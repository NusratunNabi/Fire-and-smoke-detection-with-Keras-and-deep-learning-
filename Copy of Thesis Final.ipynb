# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Step 1: Environment Setup and Import Libraries**

# %%
# Install necessary libraries
# !pip install tensorflow keras opencv-python matplotlib scikit-learn

# Import necessary libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from tensorflow.keras.applications import MobileNetV2, InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from google.colab import drive
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)

# %%
import tensorflow as tf
from tensorflow import keras

# Check versions
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")

# Upgrade TensorFlow if necessary
# !pip install --upgrade tensorflow keras
# Out:
# TensorFlow version: 2.17.0
# Keras version: 3.4.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)

# %%
# !pip cache purge
# Out:
# Files removed: 2886

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Force TensorFlow to use CPU

# %%
# Import necessary libraries
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout

# Load MobileNetV2 with pretrained weights from ImageNet
base_model = MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model layers
base_model.trainable = False

# Create a Sequential model
model = Sequential([
    base_model,  # Add base model
    GlobalAveragePooling2D(),  # Use GlobalAveragePooling2D instead of Flatten
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # For binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
#model.summary()

# %%
# Create a Sequential model
model = Sequential([
    base_model,  # Add base model
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
#model.summary()

# %% [markdown]
# **Step 2: Dataset Setup and Loading**

# %%
# Load training data with binary classification
train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),  # Resizing images to fit the model input size
    batch_size=32,
    class_mode='binary',  # This converts the labels to binary (0 or 1)
    subset='training'
)

# Load validation data with binary classification
validation_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',  # This ensures the labels are also binary for validation
    subset='validation'
)
# Out:
# Found 3688 images belonging to 3 classes.
# Found 921 images belonging to 3 classes.

# %%
# Add a final output layer for binary classification
model = Sequential([
    base_model,  # Pre-trained model (MobileNetV2 or similar)
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Binary output (0 or 1)
])

# Compile the model using binary_crossentropy for binary classification
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Mount Google Drive to access the dataset
drive.mount('/content/drive')

# Define the path to the dataset
dataset_path = '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset'  # Update with the actual path to your dataset

# Use ImageDataGenerator for loading and augmenting images
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)  # Split 80% training and 20% validation

# Load training data
train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),  # Resizing images for MobileNetV2
    batch_size=32,
    class_mode='binary',
    subset='training'
)

# Load validation data
validation_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 3688 images belonging to 3 classes.
# Found 921 images belonging to 3 classes.

# %% [markdown]
# ### **Step 3: Model Selection (Using MobileNetV2)**

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %%
# !pip install tensorflow --upgrade
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
# Import necessary libraries
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Load MobileNetV2 model with pre-trained weights from ImageNet
base_model = MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')

# Freeze the base model layers to prevent them from being updated during training
base_model.trainable = False

# Create a Sequential model and add custom layers on top of MobileNetV2
model = Sequential([
    base_model,  # Pre-trained base model
    GlobalAveragePooling2D(),  # Replace Flatten with GlobalAveragePooling
    Dense(128, activation='relu'),  # Fully connected layer
    Dropout(0.5),  # Dropout to prevent overfitting
    Dense(1, activation='sigmoid')  # Output layer for binary classification (fire or no fire)
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Display the model architecture
#model.summary()

# %% [markdown]
# ### **Step 4: Handling Class Imbalance**

# %%
# Check the unique class labels
print(np.unique(train_data.classes))
# Out:
# [2]

# %%
import numpy as np

# Assuming train_data or validation_data is defined and loaded
# Extract the class labels from the dataset (e.g., from train_data)
class_labels = np.array(train_data.classes)  # Assuming you're using train_data

# Print the unique class labels to check if they are correct
print("Unique class labels:", np.unique(class_labels))
# Out:
# Unique class labels: [2]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Initialize ImageDataGenerator for training data
train_datagen = ImageDataGenerator(rescale=1.0/255)  # Rescale pixel values to [0, 1]

# Define the train_data using flow_from_directory
train_data = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/Fire and Smoke',
    target_size=(224, 224),  # Set your desired image size
    batch_size=32,
    class_mode='categorical'  # Adjust according to your problem (binary, categorical, etc.)
)

# Now you can extract class labels
class_labels = np.array(train_data.classes)
print("Unique class labels:", np.unique(class_labels))
# Out:
# Found 0 images belonging to 2 classes.
# Unique class labels: []

# %%
# Ensure class labels are integers
class_labels = train_data.classes.astype(int)

# %%
# Example mapping of string labels to integers
label_map = {'fire': 0, 'non-fire': 1}
class_labels = np.array([label_map[label] for label in train_data.classes])

# Verify the class labels are now integers
print("Mapped integer class labels:", np.unique(class_labels))
# Out:
# Mapped integer class labels: []

# %%
# Check the data type of train_data.classes
print("Data type of train_data.classes:", type(train_data.classes))
print("Unique class labels:", np.unique(train_data.classes))
print("Classes array:", train_data.classes)
# Out:
# Data type of train_data.classes: <class 'numpy.ndarray'>
# Unique class labels: []
# Classes array: []

# %%
# Ensure class_labels is a NumPy array of integers
class_labels = np.array(train_data.classes, dtype=int)

# %%
# Convert to NumPy array of integers
class_labels = np.array(train_data.classes, dtype=int)
print("Converted class labels:", class_labels)
# Out:
# Converted class labels: []

# %%
# Count the occurrences of each class
unique_classes, counts = np.unique(class_labels, return_counts=True)

# Calculate the total number of samples
total_samples = len(class_labels)

# Manually compute weights
class_weights_dict = {cls: total_samples / (len(unique_classes) * count) for cls, count in zip(unique_classes, counts)}
print(f"Manually Computed Class Weights: {class_weights_dict}")
# Out:
# Manually Computed Class Weights: {}

# %% [markdown]
# # **Step 5: Training the Model**

# %%
print(f"Class labels shape: {class_labels.shape}, type: {class_labels.dtype}")
# Out:
# Class labels shape: (0,), type: int64

# %%
# Import necessary libraries
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# Ensure train_data has been defined and loaded
if 'train_data' not in locals() or train_data is None:
    raise ValueError("train_data is not defined or is None.")
if 'validation_data' not in locals() or validation_data is None:
    raise ValueError("validation_data is not defined or is None.")

# Ensure class_labels is defined
class_labels = np.array(train_data.classes)

# Check the unique class labels and their types
unique_classes = np.unique(class_labels)
print(f"Unique classes: {unique_classes}")

# Print class_labels for debugging
print(f"Class labels: {class_labels}")
print(f"Class labels shape: {class_labels.shape}, type: {class_labels.dtype}")

# Ensure class_labels is of integer type
if not np.issubdtype(class_labels.dtype, np.integer):
    print("Converting class_labels to integers.")
    class_labels = class_labels.astype(int)

# Calculate class weights
try:
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=unique_classes,
        y=class_labels
    )
    # Convert to dictionary if class_weights is successfully computed
    class_weights_dict = dict(enumerate(class_weights))
    print(f"Class Weights: {class_weights_dict}")

except Exception as e:
    class_weights_dict = None  # Set to None if an error occurs
    print(f"Error computing class weights: {e}")

# Print training and validation data details
print(f"Training samples: {train_data.samples}, Validation samples: {validation_data.samples}")
print(f"Train data batch size: {train_data.batch_size}, Validation data batch size: {validation_data.batch_size}")

# Train the model with or without class weights
try:
    history = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=20,  # Adjust the number of epochs based on performance
        steps_per_epoch=train_data.samples // train_data.batch_size,
        validation_steps=validation_data.samples // validation_data.batch_size,
        class_weight=class_weights_dict if class_weights_dict is not None else None  # Use the computed class weights if available
    )
except ValueError as ve:
    print(f"ValueError: {ve}")
except Exception as e:
    print(f"An error occurred during model training: {e}")
# Out:
# Unique classes: []
# Class labels: []
# Class labels shape: (0,), type: int32
# Error computing class weights: arrays used as indices must be of integer (or boolean) type
# Training samples: 0, Validation samples: 921
# Train data batch size: 32, Validation data batch size: 32
# ValueError: Must provide at least one structure

# %% [markdown]
# ### **Step 6: Evaluating the Model**

# %%
image_files = []
for root, dirs, files in os.walk(data_path):
    for file in files:
        if file.endswith(('.jpg', '.png', '.jpeg')):
            image_files.append(os.path.join(root, file))

print(f"Number of images in the dataset: {len(image_files)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cfe1812e29ee> in <cell line: 2>()
#       1 image_files = []
# ----> 2 for root, dirs, files in os.walk(data_path):
#       3     for file in files:
#       4         if file.endswith(('.jpg', '.png', '.jpeg')):
#       5             image_files.append(os.path.join(root, file))
#
# NameError: name 'os' is not defined

# %%
if 'validation_data' not in locals():
    raise ValueError("validation_data is not defined.")

# %%
if validation_data is None:
    raise ValueError("validation_data is None.")

# %%
if isinstance(validation_data, (tf.keras.utils.Sequence, tf.data.Dataset)):
    print("validation_data is a valid generator or dataset.")
else:
    raise TypeError("validation_data is not a valid generator or dataset.")
# Out:
# validation_data is a valid generator or dataset.

# %%
# Define the target size for image resizing
height = 224  # or any desired height
width = 224   # or any desired width
batch_size = 32  # Define your batch size

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the target size for image resizing
height = 224  # Set your desired height
width = 224   # Set your desired width
batch_size = 32  # Define your batch size

# Example setup for validation data
val_datagen = ImageDataGenerator(rescale=1.0/255)  # Rescaling if needed

validation_data = val_datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset',
    target_size=(height, width),  # Set your desired image size
    batch_size=batch_size,
    class_mode='categorical'  # Adjust according to your problem (binary, categorical, etc.)
)
# Out:
# Found 4609 images belonging to 3 classes.

# %%
print(f"Validation data: {validation_data}")
print(f"Number of samples in validation data: {validation_data.samples}")
# Out:
# Validation data: <keras.src.legacy.preprocessing.image.DirectoryIterator object at 0x7c0a5f7bb490>
# Number of samples in validation data: 4609

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the target size for image resizing
height = 224  # Set your desired height
width = 224   # Set your desired width
batch_size = 32  # Define your batch size

# Example setup for validation data
val_datagen = ImageDataGenerator(rescale=1.0/255)  # Rescaling if needed

# Define the validation data
validation_data = val_datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/Fire and Smoke',
    target_size=(height, width),  # Set your desired image size
    batch_size=batch_size,
    class_mode='categorical'  # Adjust according to your problem (binary, categorical, etc.)
)

# Check if validation_data is not empty
if validation_data is None or len(validation_data) == 0:
    print("Warning: validation_data is empty or None.")
else:
    # Proceed with evaluation
    val_loss, val_accuracy = model.evaluate(validation_data)
    print(f"Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# Found 0 images belonging to 2 classes.
# Warning: validation_data is empty or None.

# %%
# Check if validation_data is defined
if 'validation_data' not in locals():
    raise ValueError("validation_data is not defined.")

# Check if validation_data is not None
if validation_data is None:
    raise ValueError("validation_data is None.")

# Check if validation_data is a valid type
if not isinstance(validation_data, (tf.keras.utils.Sequence, tf.data.Dataset)):
    raise TypeError("validation_data is not a valid generator or dataset.")

# If it's a generator or dataset, print its type
print(f"Validation data type: {type(validation_data)}")

# If it has a shape attribute, print its shape
if hasattr(validation_data, 'shape'):
    print(f"Validation data shape: {validation_data.shape}")
# Out:
# Validation data type: <class 'keras.src.legacy.preprocessing.image.DirectoryIterator'>

# %%
# Check if validation_data is defined and contains data
if 'validation_data' not in locals() or validation_data is None:
    raise ValueError("validation_data is not defined or is None.")

# Evaluate the model on the validation data
try:
    val_loss, val_accuracy = model.evaluate(validation_data)
    print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
except Exception as e:
    print(f"Error during evaluation: {e}")

# Generate predictions
try:
    Y_pred = model.predict(validation_data)
    y_pred = np.round(Y_pred).astype(int)

    print('Classification Report:')
    print(classification_report(validation_data.classes, y_pred))

    print('Confusion Matrix:')
    print(confusion_matrix(validation_data.classes, y_pred))
except Exception as e:
    print(f"Error during predictions: {e}")
# Out:
# Error during evaluation: Must provide at least one structure
# Error during predictions: Must provide at least one structure

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Initialize ImageDataGenerator for validation data
val_datagen = ImageDataGenerator(rescale=1.0/255)

# Assuming your validation dataset is stored in this directory
validation_data = val_datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/Fire and Smoke'
,
    target_size=(224, 224),  # Adjust to your image size
    batch_size=32,
    class_mode='categorical',  # Change according to problem type (binary, categorical, etc.)
    shuffle=False  # Don't shuffle for evaluation
)
# Out:
# Found 0 images belonging to 2 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Initialize ImageDataGenerator for validation data
val_datagen = ImageDataGenerator(rescale=1.0/255)

# Try loading validation data
try:
    validation_data = val_datagen.flow_from_directory(
        '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/Fire and Smoke',
        target_size=(224, 224),  # Adjust to your image size
        batch_size=32,
        class_mode='categorical',  # Change to 'binary' if it's binary classification
        shuffle=False
    )

    # Check if validation_data is not empty
    if validation_data is None or validation_data.samples == 0:
        raise ValueError("validation_data is empty or None.")
    else:
        print(f"Validation data has {validation_data.samples} samples.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Found 0 images belonging to 2 classes.
# Error: validation_data is empty or None.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image dimensions
height = 224  # Set your desired image height
width = 224   # Set your desired image width
batch_size = 32  # Adjust batch size based on your GPU memory

# Initialize ImageDataGenerator for validation data
val_datagen = ImageDataGenerator(rescale=1.0 / 255)  # Normalize pixel values

# Load validation data
validation_data_dir = '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset'

try:
    validation_data = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(height, width),  # Resize images to match model input
        batch_size=batch_size,
        class_mode='categorical'  # 'categorical' if you have more than 2 classes, use 'binary' for 2 classes
    )
    print(f"Validation data has {validation_data.samples} samples.")

except Exception as e:
    raise ValueError(f"Error loading validation data: {e}")
# Out:
# Found 4609 images belonging to 3 classes.
# Validation data has 4609 samples.

# %%
# Ensure you have the required libraries
from sklearn.metrics import classification_report, confusion_matrix

# Evaluate the model on the validation data
try:
    val_loss, val_accuracy = model.evaluate(validation_data, verbose=1)
    print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy * 100:.2f}%")

    # Generate predictions
    Y_pred = model.predict(validation_data)
    y_pred = np.argmax(Y_pred, axis=1)  # Change this based on your class mode (binary/categorical)

    # Print classification report and confusion matrix
    print('Classification Report:')
    print(classification_report(validation_data.classes, y_pred))

    print('Confusion Matrix:')
    print(confusion_matrix(validation_data.classes, y_pred))

except Exception as e:
    print(f"Error during evaluation: {e}")
# Out:
# Error during evaluation: Arguments `target` and `output` must have the same shape. Received: target.shape=(None, 3), output.shape=(None, 1)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])  # Adjust loss based on your task

# %% [markdown]
# ## **Step 7:Visualizing Training Performance**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Example for train and validation data
datagen = ImageDataGenerator(rescale=1.0/255)

train_data = datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/train',
    target_size=(150, 150),  # Adjust based on your model's input size
    batch_size=32,
    class_mode='categorical'  # or 'binary' depending on the number of classes
)

validation_data = datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset',
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'  # or 'binary'
)
# Out:
# Found 0 images belonging to 0 classes.
# Found 4609 images belonging to 3 classes.

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',  # Use 'binary_crossentropy' if it's a binary classification problem
    metrics=['accuracy']
)

# %%
# Example for input size (150x150) images
target_size=(150, 150)

# %%
print(f"Train data samples: {train_data.samples}")
print(f"Validation data samples: {validation_data.samples}")
print(f"Train batch size: {train_data.batch_size}")
print(f"Validation batch size: {validation_data.batch_size}")
# Out:
# Train data samples: 0
# Validation data samples: 4609
# Train batch size: 32
# Validation batch size: 32

# %%
import os

train_dir = '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/train'

# Check if the directory exists
if not os.path.exists(train_dir):
    raise ValueError(f"Training data directory does not exist at {train_dir}")

# Check if the directory contains files
if not os.listdir(train_dir):
    raise ValueError(f"No files found in the training directory {train_dir}")

# %%
# Example of a basic Sequential model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')  # Adjust for the number of classes
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/train'
validation_dir = '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/Fire and Smoke'

# ImageDataGenerator for training and validation
datagen = ImageDataGenerator(rescale=1.0/255)

train_data = datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),  # Adjust according to your model's input size
    batch_size=32,
    class_mode='categorical'  # or 'binary' depending on your classification problem
)

validation_data = datagen.flow_from_directory(
    validation_dir,
    target_size=(150, 150),  # Adjust according to your model's input size
    batch_size=32,
    class_mode='categorical'  # or 'binary'
)
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 2 classes.

# %%
print(f"Training samples: {train_data.samples}")
print(f"Validation samples: {validation_data.samples}")
# Out:
# Training samples: 0
# Validation samples: 0

# %%
# Example of a basic Sequential model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')  # Adjust for the number of classes
])

# %%
# Example compilation
model.compile(
    optimizer='adam',  # You can replace 'adam' with any other optimizer like 'sgd'
    loss='categorical_crossentropy',  # Use 'binary_crossentropy' for binary classification
    metrics=['accuracy']  # Or other metrics you want to track
)

# %%
import os

# Check if the files exist
base_dir = '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/train'
for root, dirs, files in os.walk(base_dir):
    print(f"Found directory: {root}")
    for name in files:
        print(name)
# Out:
# Found directory: /content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/train
# image_629_jpg.rf.75f1672beb17b98264850fbed250f666.jpg
# image_629_jpg.rf.56760bfa5bb82765bba3d6be0cae64b3.jpg
# image_637_jpg.rf.cf1f2b2a8e51087d50e6b69e1fae58a6.jpg
# image_624_jpg.rf.3174a182930dbe68763d27ebc964a529.jpg
# image_624_jpg.rf.b3e7aa92e9ace40070e9d6cf806d9c28.jpg
# image_644_jpg.rf.74f5bbb5d40fab678d0a6431bf7e47ac.jpg
# image_632_jpg.rf.6825136e6592dab453aff9ba3716bfc5.jpg
# image_639_jpg.rf.180eea90ab0cc8885486df78a5b7332e.jpg
# image_645_jpg.rf.38e46d4c8c034a89de5dafbdd794d370.jpg
# image_645_jpg.rf.824c80c42927ef79b516d4ff26600cde.jpg
# image_639_jpg.rf.bf3d637577f3bab10e9540c7f3ecf596.jpg
# image_630_jpg.rf.75ed4987e198fe077a3767489fc70a52.jpg
# image_621_jpg.rf.1ae0d0ec60439088dd36c9836abcaeea.jpg
# image_638_jpg.rf.ca6e82ab520fca6770829ddc89af19fd.jpg
# image_632_jpg.rf.6fd9f029eaf3e86e95bc2a7f5f7a40b7.jpg
# image_627_jpg.rf.66a1d8de10fe7e851be24ad714c3ec71.jpg
# image_644_jpg.rf.ee789186a31696bef61d22fb8c8de093.jpg
# image_637_jpg.rf.017b59fa840d1829efd5859fbe634b0b.jpg
# image_644_jpg.rf.6a9d610ccea2069f30f9b8a66929af63.jpg
# image_63_jpg.rf.7871abb9146301f5f7857c9231c8021a.jpg
# image_664_jpg.rf.eb7f9f1b6ee6c14f743de0d2ced07df3.jpg
# image_673_jpg.rf.65d3c7cc42153cee54877e2786a1f77f.jpg
# image_683_jpg.rf.05a2961e8736dc1c20536489bc81625b.jpg
# image_660_jpg.rf.3abfd65e26466379d480b6f0d2cd4237.jpg
# image_658_jpg.rf.4f23b082247316dda644564595a3483a.jpg
# image_648_jpg.rf.207d7ff4b39945a795f1a0a7d1fd64e8.jpg
# image_683_jpg.rf.fa344f33b4d678d94711af908385cfc4.jpg
# image_650_jpg.rf.8e48e1d353191872c44c5de8d57d2058.jpg
# image_674_jpg.rf.33a889efdcb18081d03044066fbe7f98.jpg
# image_670_jpg.rf.21887ce11c404f663e283a4c716552f9.jpg
# image_669_jpg.rf.e432e89e8989c4d9d763ac825aa6ec5d.jpg
# image_650_jpg.rf.93a0b87500d6e32cb8dd664e8e707e35.jpg
# image_683_jpg.rf.eeb709d3fe6663dbb74625c827f34739.jpg
# image_658_jpg.rf.6183fb3aab79bdf9dc9599313f800ec9.jpg
# image_648_jpg.rf.899674e2f6ef3e5c1268b037204e3a89.jpg
# image_648_jpg.rf.5936d8f85937e559b0c12980ba58d1b9.jpg
# image_660_jpg.rf.3dfa43c1bc50804a71572de0f4a9442b.jpg
# image_674_jpg.rf.b43654c24ff9ad749c8249c91c6c01ca.jpg
# image_664_jpg.rf.6cd6a312aebf5a796cffbad322a4285c.jpg
# image_67_jpg.rf.b96afca954addab4474de0a4dfc1449e.jpg
# image_660_jpg.rf.f5b14be6808b9102c9521f4d11d79af0.jpg
# image_658_jpg.rf.d96a4daffb99de18a4e6016b83edfcd2.jpg
# image_67_jpg.rf.59b950055d5f0d3ef32e4dc18873eeeb.jpg
# image_669_jpg.rf.07265b01ba7850b158c99d23f236d34a.jpg
# image_673_jpg.rf.669d2b118326c30ddafe90ab24db1469.jpg
# image_670_jpg.rf.aec65fb7b09a2573b65feafb87ee79f0.jpg
# image_671_jpg.rf.aec77d07af2c216dd46120b829a0e7cb.jpg
# image_664_jpg.rf.19f904f9afb5273fe63930c0db92099b.jpg
# image_671_jpg.rf.80b50a2115a364728083c683ba2ce6d6.jpg
# image_671_jpg.rf.a2da0392325141a81d451e2dd7291e8d.jpg
# image_670_jpg.rf.e5ee54f4478851211fa93fb312b3bdd1.jpg
# image_669_jpg.rf.0f224aafdbd81235973b5ff2604fa1c4.jpg
# image_673_jpg.rf.bec32a0df9c5fccca540b033d474210d.jpg
# image_674_jpg.rf.0ea097ecf386b19f113d152199e0d216.jpg
# image_650_jpg.rf.08d4056ccace4c1a8544f78dd713ba95.jpg
# image_67_jpg.rf.6b8fc463d288655dc746991748b73dc4.jpg
# image_708_jpg.rf.817c326cd1043cc37f606fc6d8951632.jpg
# image_687_jpg.rf.6abb74af3e9e79da054f84bf1d4aba3b.jpg
# image_717_jpg.rf.9e891c31eac3b7af9c4e65394979de25.jpg
# image_688_jpg.rf.09494b5e8882beb36c0a21c272e0b6cc.jpg
# image_717_jpg.rf.2e22fdbf81a0988a0e5aa394d124a4ff.jpg
# image_699_jpg.rf.f2fe8e2b6f9456d2d218587165d48eb8.jpg
# image_696_jpg.rf.df7b4e2c8e9148b3e3a25306d1b4cc8e.jpg
# image_694_jpg.rf.6579df3ceb1195c52d3ec2dff0cbcf3f.jpg
# image_692_jpg.rf.88ceabab8124208ffbb86dfbd8b5d7c3.jpg
# image_698_jpg.rf.4a565bfc719cdf0a9698b95d5f8efd4c.jpg
# image_708_jpg.rf.37c0ae9672d2469cd866fc9ca1163ff6.jpg
# image_688_jpg.rf.9c088f5101544cf6b0937c7bcffe3fb7.jpg
# image_696_jpg.rf.b08d0fbd15d99eb97023e9656855b9f2.jpg
# image_698_jpg.rf.44d723c0537dbb9f049943c5daab3018.jpg
# image_694_jpg.rf.c938c2c0bf33d7fee2c638e6225bd304.jpg
# image_69_jpg.rf.4fe9a4c25efe9c59a2e383268e9b2063.jpg
# image_688_jpg.rf.285b6405d21fb986c2eb4600a5cbd8bd.jpg
# image_708_jpg.rf.a67a2a22e30399d55c2d1c36444a995c.jpg
# image_706_jpg.rf.87460d7f0f85aa4ce1717387e3b53e94.jpg
# image_698_jpg.rf.ee63a5feef53c23a20ae303a8cd99963.jpg
# image_692_jpg.rf.8e586c4d3e36df6d6bc5af807fcb336c.jpg
# image_69_jpg.rf.99250b40b94efda9d6f6a18fc1f58e82.jpg
# image_687_jpg.rf.4c2e5976514ca9734664d5e90711e0a7.jpg
# image_697_jpg.rf.0ad50bbe668fa25032415d35591c09fb.jpg
# image_69_jpg.rf.4a044dc8ae007644707cbe6015e53edb.jpg
# image_694_jpg.rf.a017723e18887ddf12e8079454ac1a44.jpg
# image_717_jpg.rf.138698fa32fe144b4171127e7c6fa596.jpg
# image_706_jpg.rf.3fe908fbf37960efead3369096efc17e.jpg
# image_715_jpg.rf.af9b0816439c657be385d371fd4d0c1b.jpg
# image_715_jpg.rf.f6d5f1c437549771c61aa072b1079fbd.jpg
# image_697_jpg.rf.d33758ffb53bc2ce3d89d4a7cb5709a6.jpg
# image_699_jpg.rf.c7896012420b094c1a01433920b9f777.jpg
# image_699_jpg.rf.82ab7bf54db22dfd2fd397b95e39155b.jpg
# image_696_jpg.rf.e37f6cfca181b46f3e6d1fe108edc7c3.jpg
# image_697_jpg.rf.e7e206d490aba972b1e9e13a2455b1c7.jpg
# image_706_jpg.rf.76d2b4447341b9241c1863b45cccdfe6.jpg
# image_715_jpg.rf.ddb1ad9fe9790874978ef817bdffe87b.jpg
# image_692_jpg.rf.400cbbf52f1f604b82e9c751acc87854.jpg
# image_687_jpg.rf.9006bc07d454dc95b8d34d62bd656ed6.jpg
# image_744_jpg.rf.1387147235d323d530f8a82fa78a3296.jpg
# image_728_jpg.rf.2bf43874cfd8c62d3b3dbfb2c2c75152.jpg
# image_728_jpg.rf.dfc1ae9c930092fadfe517c2c7ad9a1e.jpg
# image_721_jpg.rf.dd2619768971e6273af76bc6fdfd64e6.jpg
# image_723_jpg.rf.2384fd3be386355310c9fc2a784b413e.jpg
# image_725_jpg.rf.6a570dedcbc496b51828727ba191e6c8.jpg
# image_73_jpg.rf.5bb2b408d723f2f40d60c38c27852479.jpg
# image_725_jpg.rf.40bc0f9e3d601942c8e4cece42202d8f.jpg
# image_747_jpg.rf.72fcc085034855c8f15fc2ec3451e2f2.jpg
# image_728_jpg.rf.6ccbc450dc350e2c79bb8c69ba3d65c4.jpg
# image_756_jpg.rf.c930baba464eaa0dbfa565f5670c5d43.jpg
# image_743_jpg.rf.7cea94e408da07e0c8863e0a5eae4578.jpg
# image_747_jpg.rf.42846ec03455f1041c868ad4b92d243a.jpg
# image_756_jpg.rf.c7e251d58016ab678f71142b01ba8e6a.jpg
# image_746_jpg.rf.9bc3a57daccc0c761270e02747fd6454.jpg
# image_721_jpg.rf.44a6cfa7f50b1b4db2392ea5137d4f89.jpg
# image_739_jpg.rf.1b1ab2f42e9f41680793a93cd4e69ac5.jpg
# image_73_jpg.rf.303dbbaee2531afd7ea0b9165b1a25c9.jpg
# image_744_jpg.rf.2e51e90add1d1e05182fed517e113250.jpg
# image_739_jpg.rf.ba743143ff46dea253076eb7e8d9a550.jpg
# image_756_jpg.rf.b1ceea75a80b5bfb0381ea099982edbb.jpg
# image_725_jpg.rf.116b80bc8a454e53fdf2d55e8dcc54fb.jpg
# image_747_jpg.rf.95faf078aa454fca729f8249d4393a78.jpg
# image_746_jpg.rf.6cf77df239dbe486a1a5f644dfe08e01.jpg
# image_726_jpg.rf.0edf5d88684575304b717f1e2c986808.jpg
# image_743_jpg.rf.8afc1530e3d40a65f9021873ec002a6c.jpg
# image_752_jpg.rf.16352c386ae4ce9c789904a2ecc47ebc.jpg
# image_752_jpg.rf.138e7406cdc3c5bf8d2a022fc67c61f9.jpg
# image_739_jpg.rf.4d0fe9d7beca80e3eb3cdcd0b1eaa818.jpg
# image_726_jpg.rf.d4bde47a9bc75de9979f8eabf3c074b2.jpg
# image_744_jpg.rf.27892997b7e7d5ecb5b1742913a59209.jpg
# image_752_jpg.rf.584278b906b0aa1c919edd3a88416ebd.jpg
# image_743_jpg.rf.cda4f0a56b311c9ce6e38cf968822354.jpg
# image_723_jpg.rf.b1cc68a21851c39d00237b38c4ea4e8c.jpg
# image_73_jpg.rf.043932569719265d71de20e46a17f941.jpg
# image_721_jpg.rf.baac2cde260f25133f042f0846dc7b43.jpg
# image_726_jpg.rf.aadc1609b7d72f7bf3af3f9ac6414e2f.jpg
# image_723_jpg.rf.42056c53d5d7cf8f60a2a4e65fe3dc6d.jpg
# image_746_jpg.rf.ae6c856be7a96f55d171850cd022229a.jpg
# image_774_jpg.rf.ab02d4b2aace50cfe0ae777b5a7e7303.jpg
# image_759_jpg.rf.fd251820f7a79c921a5b186d4bae1952.jpg
# image_762_jpg.rf.5754f05d2765b135b05b667df9172262.jpg
# image_774_jpg.rf.8ee7c5176345c9d8014221df9ec424ab.jpg
# image_758_jpg.rf.400dee7194980808f8209206bd938599.jpg
# image_778_jpg.rf.cc6e2b751ad1f0b1fa80317e214406f1.jpg
# image_781_jpg.rf.f1a29250cb5d3005806b6e5722aa74d7.jpg
# image_762_jpg.rf.9b4a36047d50281b5d1dd2a08a4ad68d.jpg
# image_781_jpg.rf.62e80af6fa83497fdc283e08c9900283.jpg
# image_762_jpg.rf.790ae078acd33f885cf8444a4124b651.jpg
# image_783_jpg.rf.91592b52d24b1c5ba5ec7f11eae82c7e.jpg
# image_788_jpg.rf.e183e99924bd2e1a799b540b68b81139.jpg
# image_784_jpg.rf.f3c96108a7b1bbcf8bd018f7479c6518.jpg
# image_778_jpg.rf.5c729e2051afcd0bba0c9032e63cc797.jpg
# image_760_jpg.rf.4315652bfa9c365656099be351640684.jpg
# image_788_jpg.rf.ad540dd7fd86ef4f5317134a6bed925d.jpg
# image_764_jpg.rf.e104569feb00ce5cb6c8c9de944feb7d.jpg
# image_760_jpg.rf.261ab065e786a81151d74e31fe4b865d.jpg
# image_760_jpg.rf.e6a0e9f6c34a29d756f1911a9b14c125.jpg
# image_787_jpg.rf.887e75e9af357aa21cf2265f28833356.jpg
# image_784_jpg.rf.1e4c54a0dd2adf431c0d6990b0ceb387.jpg
# image_781_jpg.rf.2e120e6f4f1287a976c598eb08edaca0.jpg
# image_784_jpg.rf.a0f22365d672388e173d7e8be2463c33.jpg
# image_787_jpg.rf.65fb283437794b46a4387ae14c83bbf3.jpg
# image_758_jpg.rf.5bbea9ed6c623cd6fd85dc42859fe932.jpg
# image_764_jpg.rf.ad4abf2cbb7edfb4615ae01e3cdccc7f.jpg
# image_788_jpg.rf.cd7029653a023a7bfa54e44f3bf6befe.jpg
# image_778_jpg.rf.b254a1e9d6dfcc71628d5bc28e7d42cd.jpg
# image_758_jpg.rf.9c355294cd566e1d39f407e301ad04b4.jpg
# image_759_jpg.rf.d3804c3ca377338c6307875244287d9d.jpg
# image_783_jpg.rf.e6e7bbe3facc66f9434e9ad80ec8bee7.jpg
# image_783_jpg.rf.2848e62769734fb640460f9973b9da25.jpg
# image_787_jpg.rf.05a2d220fb0b8ba813561b221bac80a2.jpg
# image_774_jpg.rf.4d6aa387c9e2844c583f483ba024c928.jpg
# image_764_jpg.rf.3b8a0d685327d88b04413a80ce924b4b.jpg
# image_759_jpg.rf.f20f78ecc177c5883da4c63fbcb2a22b.jpg
# image_811_jpg.rf.0df9627cff2a9a34b2598fd4a355d7f5.jpg
# image_810_jpg.rf.8e1513bde4a085d635802a98b7fd3ada.jpg
# image_793_jpg.rf.38238e105f3d58c2482577f60ad646dc.jpg
# image_798_jpg.rf.a7722e37b175ee88840313e2c3961d06.jpg
# image_796_jpg.rf.20df3320abbd61bab6257881422be01c.jpg
# image_794_jpg.rf.07f64d90f64fa609ed4a9fd098cb8c6f.jpg
# image_803_jpg.rf.054fab9ad1d8f0f2f3480c2733da0861.jpg
# image_793_jpg.rf.84c379f61d460bfd06d00719279daccc.jpg
# image_810_jpg.rf.49c82d2366ba33c4dec67756eea32016.jpg
# image_78_jpg.rf.031362e3452b1bb25e265dd8e5e88e0b.jpg
# image_79_jpg.rf.457083c8e2925d5d8ea7097d4700ac78.jpg
# image_798_jpg.rf.5cd950cdee2eea8009c37199d0011a3d.jpg
# image_793_jpg.rf.28bff8def9307b6687abfdea756e2048.jpg
# image_801_jpg.rf.264bb55c6d82b0b2fa700b7ad9ce431e.jpg
# image_804_jpg.rf.e53cfb85a62febc1fab2ca776dbce637.jpg
# image_794_jpg.rf.9a2f491fdec2bf0115d02cbbc5bd9d50.jpg
# image_797_jpg.rf.3f270bd71f153a17b45d6770365a389a.jpg
# image_796_jpg.rf.b3c8cf3f71a6ff3ace50f5c873285e32.jpg
# image_801_jpg.rf.6096c7e01d437e548ab461df40d59e43.jpg
# image_798_jpg.rf.b6968c1e63b455b3abd03657e6e96090.jpg
# image_804_jpg.rf.c5af8c50fa62c96a696d12e0dbeefe43.jpg
# image_794_jpg.rf.d08930cd7b27ef0842e135baf8d88d9b.jpg
# image_801_jpg.rf.ca215ad3c0dffbafe6bb932ad51a3faf.jpg
# image_796_jpg.rf.101fa201e5295331355a01d15b544140.jpg
# image_811_jpg.rf.50de77aae4dfeb49bb2ea47e501a5145.jpg
# image_810_jpg.rf.9b914cb380e9ca41a7bb2debf4618d34.jpg
# image_79_jpg.rf.d81b175e1ae99999b386ff34f90a1a32.jpg
# image_803_jpg.rf.02cb95e47d0efa41e51ba2d2b6301145.jpg
# image_797_jpg.rf.11d734fc794dace4b89947cd6eb175e1.jpg
# image_78_jpg.rf.cb2aa3c265b4114e19609104770f0c80.jpg
# image_79_jpg.rf.55175c85f22731272765f7a7179f716a.jpg
# image_797_jpg.rf.11f928fa13062e0973a74f0bb59f7a78.jpg
# image_803_jpg.rf.b39b22c880eb912fa0011ccd5cdb9464.jpg
# image_804_jpg.rf.357b1f151bdb8bc6d8ea0702f5c86aca.jpg
# image_78_jpg.rf.b027c145b39fed6a1db1c7e582b97123.jpg
# image_825_jpg.rf.20bf0e5b223453db731134b7d51ff0bb.jpg
# image_828_jpg.rf.36c9a049fe2faf5b90da2c10f49998e3.jpg
# image_830_jpg.rf.8131f4697b93663b170a92d3056b6898.jpg
# image_819_jpg.rf.bf506ea08044a071732e0a49be5b0c80.jpg
# image_814_jpg.rf.5be86d4fe9bf2f6215d962b8a8487746.jpg
# image_831_jpg.rf.e3409e8b65f12eb70167ade76a06fc1d.jpg
# image_831_jpg.rf.6e7ed88f6c27aa8b01ba04a70f7e69a4.jpg
# image_825_jpg.rf.d876e11f21ff5ffc14da744fd65175b2.jpg
# image_811_jpg.rf.f653044fc325a5ac245df73a1e7e0ce6.jpg
# image_829_jpg.rf.6d0fed68d03e591a806b11dcc0edbdbd.jpg
# image_814_jpg.rf.c10fb336fa6f55a0e530549cf809445c.jpg
# image_835_jpg.rf.6f1f70ddf6864d4f1335170c1f0a54fd.jpg
# image_835_jpg.rf.a57da375aa06a4a7e6c5f7aa8d89657b.jpg
# image_829_jpg.rf.0e4604e0acf58313a9bf8c5372cc01b6.jpg
# image_831_jpg.rf.b00f41cfb990d5d2d125cc40046023fb.jpg
# image_82_jpg.rf.803e9f8cf4e75ec1bf19661d86f1ebd2.jpg
# image_815_jpg.rf.2500979fbd5b09cc8b79eb91731ce06d.jpg
# image_836_jpg.rf.4ba3c728db6a8f50172b9a04fb24b8b8.jpg
# image_814_jpg.rf.839de51317aa9876ed036565e8316831.jpg
# image_828_jpg.rf.e870864a4d74fed5cc20fdb1de2599a0.jpg
# image_825_jpg.rf.b3c175aa134b32744040d65caa923c64.jpg
# image_828_jpg.rf.a0b52993038583552cbabf6dc47cdf6b.jpg
# image_81_jpg.rf.63bcc2f8b9faa63007fca815d64a01a3.jpg
# image_819_jpg.rf.debd7fafa5ca51eedb3a5b171564e685.jpg
# image_819_jpg.rf.d61512e23b7be1e18b7383c1fde783fd.jpg
# image_829_jpg.rf.1235d489b90dcb8b3caf8df2cd10b77e.jpg
# image_82_jpg.rf.72d075268588a682d5a337bb1e304ae3.jpg
# image_82_jpg.rf.e89ebc2b9afea737d82045ab6087a30c.jpg
# image_836_jpg.rf.3688f608ab9baed58d121608fc254e80.jpg
# image_815_jpg.rf.265cebfe6664474efc60bf787cd93333.jpg
# image_81_jpg.rf.a893369a445250b3cd777a21daab87f4.jpg
# image_836_jpg.rf.cca58a4059dcd6196521ad949856b0ef.jpg
# image_815_jpg.rf.420e0b7264f067b908cc7c7e0df885c4.jpg
# image_81_jpg.rf.13502e78aafbcdd78e990d2b2f47669c.jpg
# image_837_jpg.rf.05ef80af68004275560e6d2a35ff25c7.jpg
# image_830_jpg.rf.0ec042f441d9900db5b8c29580c70e8f.jpg
# image_830_jpg.rf.6b7d19a41f76bb5dfc31a93c018ea619.jpg
# image_835_jpg.rf.655fb7db41cf193a5b031be238db4b71.jpg
# image_870_jpg.rf.ec8b40292694b93ef331a3c59179a1cf.jpg
# image_852_jpg.rf.e8cac92be93bd29733301dcfd0c0f922.jpg
# image_873_jpg.rf.a875aac06b23535d0aad09da27029790.jpg
# image_870_jpg.rf.8c7904b4fa4b2ab15fb1f91f14a02719.jpg
# image_861_jpg.rf.5ea21b4a148d79dccdb77425a0794cad.jpg
# image_873_jpg.rf.c53b8e75e534ee7bff9584ff803c375d.jpg
# image_844_jpg.rf.5a021f607822665674918db1b3d0dbe6.jpg
# image_837_jpg.rf.7867d0f243461bb80c1af8d087337e69.jpg
# image_85_jpg.rf.b6052c2de96358b77b521362b83827fe.jpg
# image_86_jpg.rf.deae58574f1d55b5898f573f84b5681b.jpg
# image_867_jpg.rf.016e24da216fd6fda317c64ffc833496.jpg
# image_861_jpg.rf.14fa3b158b57dfac3b4305df8045ed5a.jpg
# image_844_jpg.rf.2b47966bedcea7aeb55f7f0eaa1ef208.jpg
# image_85_jpg.rf.5abb7f138ada388d87038a1ff80b4790.jpg
# image_862_jpg.rf.c7ba80111463a1f9321320db7fba6801.jpg
# image_854_jpg.rf.3f20d37c6cf1af6986ef51939602af33.jpg
# image_844_jpg.rf.90bea561eb6b9cbd4a863f5ca45d6c3d.jpg
# image_867_jpg.rf.45b5442ddb5433af8d8316238f928c8a.jpg
# image_870_jpg.rf.af76cfda15f9da083e195b444d56ddf2.jpg
# image_867_jpg.rf.5d29e74d7d24ba5698e45dbfc14881f3.jpg
# image_872_jpg.rf.c8e4cec2dfe91a5c93ce26d1b1a9ac15.jpg
# image_854_jpg.rf.757b6cdf9133b7af814f2819ebe36063.jpg
# image_84_jpg.rf.dfcb89c27fdbac254c103f98d26b8c40.jpg
# image_862_jpg.rf.12251c1637bcec01cac0a05202035d5f.jpg
# image_872_jpg.rf.c3e60d18ed339e133542e87c7f062bd4.jpg
# image_85_jpg.rf.fb52e36df8bbf5705064c0b2440bc418.jpg
# image_84_jpg.rf.78386e5459f08fa1cab035c7b389c95e.jpg
# image_852_jpg.rf.70810f14c41d121537654ed9ec4399bf.jpg
# image_837_jpg.rf.3a4834ff3f2e7a39f7c659867c7f1bea.jpg
# image_86_jpg.rf.32167f9b65c16c8dfe4c1c56647c8784.jpg
# image_852_jpg.rf.ca1bee84f928489e15d3223ec6eee4a6.jpg
# image_862_jpg.rf.1b0f199d08a58841eb5fd260c0358488.jpg
# image_84_jpg.rf.2c2a754f5387f2bedb56fc22314d350d.jpg
# image_86_jpg.rf.320d6a91b18be86514bfce6b7b8ebf21.jpg
# image_854_jpg.rf.ef9384a3acd9ae5ace5cbadd0b848192.jpg
# image_872_jpg.rf.5ab56e3cf876492f82b0a441bc912458.jpg
# image_861_jpg.rf.ca612dd376465d554c3048379654b0d1.jpg
# image_87_jpg.rf.966d82f490d9a2b5f4f3535c05c36421.jpg
# image_890_jpg.rf.315061598b0cb03ba8c76ecea4816c46.jpg
# image_886_jpg.rf.c510517e4b7c862f31e8cf11c6b297ab.jpg
# image_884_jpg.rf.77c1bcd987eca82f90b16f13a0dc390d.jpg
# image_892_jpg.rf.b6f3760bfdf29b284b1fb2e43d197c53.jpg
# image_87_jpg.rf.c49db277981bb45473b9a2f900b23a37.jpg
# image_891_jpg.rf.699ffa3ac14fb5abe81cc8ba4dfcbd92.jpg
# image_887_jpg.rf.c7af9e672331597abaf5413d210c57ae.jpg
# image_884_jpg.rf.69a65d0ee377500853d3e294c3bdb59b.jpg
# image_94_jpg.rf.6b1a19c08f61ff1a4bb1831b0f368e8d.jpg
# image_899_jpg.rf.b12b39b7dfa2162efd204356d4bd4864.jpg
# image_90_jpg.rf.7ed19f645eea999274edd1c767c11068.jpg
# image_883_jpg.rf.f6c378fb55b8b0ac6c8916c89729b2a6.jpg
# image_887_jpg.rf.9d65701d9a56478969e701ed987c5003.jpg
# image_98_jpg.rf.12b70a013954cdbfb40b3916f12528d1.jpg
# image_886_jpg.rf.49ed011b4b605bc8e6c56f3e87e5ccd4.jpg
# image_899_jpg.rf.b5d919a868eaedb9f7e26b12a7ed29e2.jpg
# image_881_jpg.rf.4ca6a52351619602aeb12c48cc7dad0d.jpg
# image_891_jpg.rf.ab6aa8c58e5710a01146a67c3495094c.jpg
# image_881_jpg.rf.cc07cb20f9016b36f51d3a89be8d3702.jpg
# image_90_jpg.rf.0576959d2cd15bda3335bcea118d4b4d.jpg
# image_892_jpg.rf.badbfec927ce71dbca327752149626f0.jpg
# image_899_jpg.rf.022c7c3c517dacd30e98b2c169b5433e.jpg
# image_881_jpg.rf.4ea5e15bc1434c4bb1a1f8e17d1694ef.jpg
# image_886_jpg.rf.a85c3883702ddffe69c066f9b99acfdf.jpg
# image_90_jpg.rf.d80a8648651e5575ff706c908a144a32.jpg
# image_890_jpg.rf.b1c59e30c8a085fcbdb94cc7493b68c2.jpg
# image_873_jpg.rf.cdca4917d267989d8d545a72b2f34659.jpg
# image_94_jpg.rf.d84b75dfd6ce9aec4bfee3445ecced8c.jpg
# image_884_jpg.rf.2215cf96ae9800c7555f8861375f6548.jpg
# image_94_jpg.rf.eb266e106e1648704892e97b9857e225.jpg
# image_892_jpg.rf.ca46ffe570035d87b9a9f46a3df15136.jpg
# image_883_jpg.rf.48ad460035e6dfc265da10f0b3f0fef1.jpg
# image_891_jpg.rf.eba06e78e7d19d4b149cddf1046285ec.jpg
# image_890_jpg.rf.11e877612035cffa50e983f88a12a788.jpg
# image_883_jpg.rf.c6534bc2adb449ad00f4e391088e5488.jpg
# image_887_jpg.rf.d8cce142adfc8aef6328a0bde72bab01.jpg
# image_87_jpg.rf.0242f1962a2e60e5cc2864d748954f75.jpg
# img-106-_jpg.rf.e635ca6e2758a0228e1ec6e51a463368.jpg
# img-106-_jpg.rf.8b50dc35481511e81b27503137d96dbe.jpg
# image_9_jpg.rf.be9bc8ca1f44eb886eaa068f114b7f01.jpg
# image_9_jpg.rf.15c91b540df14f647f786a75d5ca1ed0.jpg
# img-106-_jpg.rf.98234a016dfb94034e6b26a69654a993.jpg
# img-105-_jpg.rf.60d48ed68c4c61a332cba6a51870c8ee.jpg
# img-103-_jpg.rf.ff90fe903555e73e83bbcca674dd760a.jpg
# img-104-_jpg.rf.49b6b3b248100dad7efd3b8a5d6902c3.jpg
# img-10-_jpg.rf.5f22c4cd9e667d639ac4b94dcfb7cbbf.jpg
# img-105-_jpg.rf.5b5a2287ce27f1bbb3e3a26cc062351e.jpg
# img-104-_jpg.rf.63b7e3e7456f11c93ad43c2d707ac22a.jpg
# img-108-_jpg.rf.2646e423806e63d6f38a0b13fc1360fe.jpg
# img-102-_jpg.rf.14dff15287f3b5d6b53c2ff38e4ee298.jpg
# img-101-_jpg.rf.30af7ebb63b8c8b1a07246125cee5690.jpg
# img-104-_jpg.rf.57b2f5bfff48559191d55f09792bd279.jpg
# img-100-_jpg.rf.a91dbec274056f9c3f8938668505e14e.jpg
# images_jpg.rf.6cf3dcb01e323dd8456a1e8e409e8565.jpg
# img-100-_jpg.rf.197cdfca3cd9253a751732576b13961e.jpg
# img-108-_jpg.rf.bdb307c6d98fe694c958beb0030313f5.jpg
# img-105-_jpg.rf.00d12eaae4bab9769994358889d9d7a0.jpg
# img-101-_jpg.rf.53029e7bb2956542e60ab65fe9e500b2.jpg
# img-103-_jpg.rf.16668cc2fe305afeedf10383d02a10e8.jpg
# img-10-_jpg.rf.4f8cb72cceaff49934fa532c8bbff982.jpg
# image_98_jpg.rf.abdf671ebfb93b7c72e831944aeba846.jpg
# image_update_img_jpg.rf.0f81f1e7c85bbb51f598f6c9b4ad63d6.jpg
# images_jpg.rf.6899cf3e89ac6ba9c9c15e78f5cd1f90.jpg
# image_98_jpg.rf.63914b943c89c3fcb29f47ccc9171698.jpg
# img-102-_jpg.rf.72ab9056364b2be869e63a097429087f.jpg
# img-102-_jpg.rf.b0a03a378ff482d4f666a40820051423.jpg
# img-108-_jpg.rf.afa5397db6ff40570e9abddd49c1a1b4.jpg
# img-103-_jpg.rf.284ad4408d012a63437b55133579d8f3.jpg
# img-101-_jpg.rf.5911dc816d78745b6906dd571accca49.jpg
# images_jpg.rf.caaf6beabc6b443710ea2f45d2402272.jpg
# img-100-_jpg.rf.026439c196fdb1ad21529d8e286962e8.jpg
# image_9_jpg.rf.7cec28b31903743a14199ce1321c6791.jpg
# image_update_img_jpg.rf.f36af7bcdf641d30cb39e7e7e941b06c.jpg
# img-10-_jpg.rf.afd5a96b812898571e85665c09444ff1.jpg
# image_update_img_jpg.rf.93720e38acfe2e898f365cd205713ad7.jpg
# img-11-_jpg.rf.af491845f52795b6960cb3b87860bc93.jpg
# img-115-_jpg.rf.5809be2c3666650cfe5d4f618b486e82.jpg
# img-124-_jpg.rf.e75088e91fce600f0d9cd6d70ba3efef.jpg
# img-119-_jpg.rf.08706403cac2b0b7cdbbfde2c0c616af.jpg
# img-121-_jpg.rf.af9febe220176782180b7ace89c420a0.jpg
# img-123-_jpg.rf.49ba67b007e2455edd01e2e592e90fb6.jpg
# img-114-_jpg.rf.afe345f7867a656ecb0566c79c304499.jpg
# img-119-_jpg.rf.a177d9cb4a957ee76b9bda0a9f1492e6.jpg
# img-111-_jpg.rf.fbebe784a2e689284bc31c79e86b2179.jpg
# img-114-_jpg.rf.74985f305e348faab260fcdb811475f2.jpg
# img-116-_jpg.rf.9c8cf55474ed30437b8e7419911dc104.jpg
# img-11-_jpg.rf.c5ec3dcc322ed20a2a55246cea0eed6c.jpg
# img-11-_jpg.rf.45f47147e417f7fd2a883dda3b9eb8a0.jpg
# img-124-_jpg.rf.d88b090f74540183168275272abec3c9.jpg
# img-110-_jpg.rf.bd2a41853ef8fd4984649379ab4d7aef.jpg
# img-121-_jpg.rf.9dd583ea9117673b174438bd61a70832.jpg
# img-117-_jpg.rf.59384c66da8afe83f93928dc30940353.jpg
# img-111-_jpg.rf.082c3ba3a41ba18aa37db0dd0d911157.jpg
# img-115-_jpg.rf.7c95f85961b9736bd7584e780c3d6b4b.jpg
# img-123-_jpg.rf.5fb575be2b3466b9000c52ec3a9eb524.jpg
# img-119-_jpg.rf.9b6eafb618d2599d9822f1b1c78e5ea6.jpg
# img-117-_jpg.rf.5c3c98c41d067d5740a40ae82d64572d.jpg
# img-109-_jpg.rf.d2ffbc278d77691bb4e02d1e16b80347.jpg
# img-110-_jpg.rf.bfcf5bab3b80c272359014af290577c1.jpg
# img-123-_jpg.rf.6e4eeb26f250bd143b0790bc3686c413.jpg
# img-115-_jpg.rf.3c210d5b74edb5f2ec64acfaa70b57b9.jpg
# img-116-_jpg.rf.8366acab54bfc86d2a8fe741e272db56.jpg
# img-117-_jpg.rf.2a6ceb7d70a4bf6d3e1cde76d7785535.jpg
# img-125-_jpg.rf.729d92cdba980a04d3fd9fbea25e02d7.jpg
# img-109-_jpg.rf.a92a86856a21f08b88a7a5ac4eed9c37.jpg
# img-114-_jpg.rf.4d539f2e2c2e1ad44ea1044d7e69e148.jpg
# img-124-_jpg.rf.44d0576a958cfc494b68f38203085d9e.jpg
# img-109-_jpg.rf.70ad49874c7346b71459e1068639c89a.jpg
# img-110-_jpg.rf.f09e5d74a8c2e4ed3816640f846198d6.jpg
# img-111-_jpg.rf.c046f764a949811e580e13b523edbaf4.jpg
# img-116-_jpg.rf.29266ba1eaf5577f4b14e50fd27b248f.jpg
# img-121-_jpg.rf.e95b02f3105e3fb0eabcf2602d4a7eeb.jpg
# img-134-_jpg.rf.f0f50042d0b1136ea006559c05296a33.jpg
# img-134-_jpg.rf.45a35e8ca50cae7f6d5405d9cedd0c92.jpg
# img-131-_jpg.rf.e66d729b480cc75328c53808a3696807.jpg
# img-137-_jpg.rf.de5cfee96007c60deba91d31ef41d935.jpg
# img-129-_jpg.rf.df3bffa61a03994c12bd77a6fea1d58a.jpg
# img-134-_jpg.rf.671899b572768db32bb17f101215965b.jpg
# img-132-_jpg.rf.5af4817c3a3ea88dc14dad4a34dc889b.jpg
# img-125-_jpg.rf.e9007890bf6a663e28cfc1ecc0694569.jpg
# img-126-_jpg.rf.6a616f0e4549dfaba510cd8ed5971c5a.jpg
# img-140-_jpg.rf.8e680b22d9ba3c44297300b58f43e785.jpg
# img-141-_jpg.rf.2147df26725c29bc5ef646e062830733.jpg
# img-131-_jpg.rf.5c2ea569480363ab9d6a9b2038e5d930.jpg
# img-133-_jpg.rf.d280aa45614335212a44839901bf5c6a.jpg
# img-125-_jpg.rf.c4e24048a749fe9a61bed14d89223e15.jpg
# img-133-_jpg.rf.1abef5c36ee1deeccb1998b56e5b3c08.jpg
# img-126-_jpg.rf.476a1f014839f225f42b00024480f072.jpg
# img-132-_jpg.rf.0a322db6953c3ed1af6795f9187ecbaf.jpg
# img-130-_jpg.rf.fd03f530e84966bb88a6df4650d29510.jpg
# img-132-_jpg.rf.a70c9591288e97feff6aaafed323687c.jpg
# img-138-_jpg.rf.1302b3a8f6ec5b2141728b1fa5fe7fcf.jpg
# img-138-_jpg.rf.28362a5f453bfdd5d889e26504d2f91d.jpg
# img-140-_jpg.rf.0a0ea3db145d5ad692d812b7aa171f45.jpg
# img-131-_jpg.rf.e0e9a350cd126e72a6899194490b6bb4.jpg
# img-133-_jpg.rf.d12f3040fde55ea3027ca2dee5203721.jpg
# img-129-_jpg.rf.a4183d4804db2a59e69a1e67ec540908.jpg
# img-130-_jpg.rf.13ff4a20e65471ea93aefc6a6fe7f2d2.jpg
# img-137-_jpg.rf.a1fb31566afd6865b5ea9510374c53e0.jpg
# img-13-_jpg.rf.82b0ea335575703d86fc852f73c37658.jpg
# img-13-_jpg.rf.23f43ca3514b1d481ab04ea8b8705f8b.jpg
# img-138-_jpg.rf.cc43e56f010a7f8772449c97ee403600.jpg
# img-13-_jpg.rf.ffe0fa46059467e83aa0f369b2e9e72a.jpg
# img-137-_jpg.rf.7b378893f2ebe250e1a66bc50fe7416a.jpg
# img-126-_jpg.rf.35b6e3d798e81a708f597c02ccc3a8bb.jpg
# img-140-_jpg.rf.290f867056790479761ac7416ee76bf2.jpg
# img-130-_jpg.rf.a11d06fb0c6ff538cec210f5ab557a6a.jpg
# img-129-_jpg.rf.e80a8ab6fa324cbe54fa0a57a5c750df.jpg
# img-147-_jpg.rf.0c7c391643ab533a72916a6841008771.jpg
# img-26-_jpg.rf.9c4c2cfca3183d778be4e5835db677fc.jpg
# img-147-_jpg.rf.bc2b7b46c1fe9d1e8ba62b9594c44c21.jpg
# img-142-_jpg.rf.72cf2a99e97e1a11fadfd6f025b81308.jpg
# img-20-_jpg.rf.f05bb76814a1085c92f0301d8237872d.jpg
# img-23-_jpg.rf.6da679306fe234bc90713b03f8e76e4a.jpg
# img-146-_jpg.rf.398a124121d2f4d7f62b5d6ae31f8cee.jpg
# img-15-_jpg.rf.0da15ceb75cc3a6c7d996fb3de796332.jpg
# img-16-_jpg.rf.f0320074728b3f7cd15bc0a503192fd6.jpg
# img-141-_jpg.rf.4f778e948f6296bfa88b5f5e3cc49bce.jpg
# img-16-_jpg.rf.5e7e8717b8c42725f4b6574b6d2c51fa.jpg
# img-19-_jpg.rf.7aa860d6a01bc54afa4f38158506af53.jpg
# img-23-_jpg.rf.c46725005bf07d7be2c08163058210b3.jpg
# img-146-_jpg.rf.2af54cc45f8bff9e59b4a7ccca7ea057.jpg
# img-146-_jpg.rf.c3154b8dfca1150c521cd7bb04ba0d4c.jpg
# img-145-_jpg.rf.ca806b92f4835f3eb4cb4387ca82e2f0.jpg
# img-145-_jpg.rf.aac63dcd86ba77fb14c303d1212ec0ed.jpg
# img-17-_jpg.rf.388726a23a4fc077f84f57c2bf6d7940.jpg
# img-23-_jpg.rf.874b4bab8a53fdd81160213966f72e96.jpg
# img-15-_jpg.rf.7787cd52f5731746145e624526aad9c0.jpg
# img-142-_jpg.rf.4553466282a50fcdf9bade6f31afd06c.jpg
# img-20-_jpg.rf.8fafbf7421ce3e21a33a032f88a7e1cf.jpg
# img-16-_jpg.rf.42023b1f807bac514cacedb4ab3232e6.jpg
# img-15-_jpg.rf.3d998604dea520f0cf1e55a4fc58a728.jpg
# img-2-_jpg.rf.c6c806a7951ede3004885df0d85827b5.jpg
# img-2-_jpg.rf.17efcc21c07c8faf026e62547502354b.jpg
# img-147-_jpg.rf.9387c9dae5550e39cd935657dd127395.jpg
# img-141-_jpg.rf.866d9bdfdf8184123e057f992bc71276.jpg
# img-17-_jpg.rf.f88fc6eeb1484d1d63510ea6a6f92201.jpg
# img-26-_jpg.rf.4b89e94774704cd8b19fadcca0b1650b.jpg
# img-142-_jpg.rf.f1af480ac6f28443e413f375786ded2e.jpg
# img-19-_jpg.rf.b32b31d16f2b2d5384eb153bcdb5e97c.jpg
# img-19-_jpg.rf.a93e77e9db2e85e7bbee5531d887c942.jpg
# img-2-_jpg.rf.77bb24c9e5b47b594749b71c353bb637.jpg
# img-145-_jpg.rf.a2c8b011bfda8f661624958f4e3db7d4.jpg
# img-26-_jpg.rf.33eddcf8ec5cf59c36253ac20512cb74.jpg
# img-20-_jpg.rf.aa512d41e418ff149fe3aa9fe0664b97.jpg
# img-17-_jpg.rf.4aa5a4dd198e37b7f276c102b9a53cce.jpg
# img-32-_jpg.rf.86f7e1d369d56a7d88fb9bfeb61f1cc2.jpg
# img-28-_jpg.rf.7e5ef9823d607a363e62936066373075.jpg
# img-29-_jpg.rf.04ed6b59cc50c78129da334188c36e08.jpg
# img-33-_jpg.rf.bc2549467694ac2caeda1089f18bc565.jpg
# img-28-_jpg.rf.b3679fa062f02a8e4a01a1e0175e87af.jpg
# img-37-_jpg.rf.55d851eb1b4e13c6170b2f555a2b6379.jpg
# img-33-_jpg.rf.41ee4731a5fd77d91d643047325b0ba9.jpg
# img-31-_jpg.rf.5c66eef63295d89cbe1a18dc7676a48a.jpg
# img-39-_jpg.rf.76a12a55b14bee66089c3606c81cfa8f.jpg
# img-32-_jpg.rf.a5efbd11c78471b8d908a9304d4238c0.jpg
# img-38-_jpg.rf.c00cf6a4ebaac423101374597bc5d529.jpg
# img-27-_jpg.rf.e765842b85afb1c83851a285dee5e5c7.jpg
# img-34-_jpg.rf.4b17dc987c0703c8403a73382b83dcfe.jpg
# img-27-_jpg.rf.dabb94979fcc4ad65fc4b82a126e9236.jpg
# img-31-_jpg.rf.7489a9bd0f9470e3293d77ddbd8b7d80.jpg
# img-33-_jpg.rf.9bf3e1cae41e913e8a8f9898023dff79.jpg
# img-29-_jpg.rf.1ec839079a335c936494bb0b3f34c58a.jpg
# img-37-_jpg.rf.4527cd23c8a9ca7b9afd67880c4d8f62.jpg
# img-3-_jpg.rf.d412709343323060f61aac59f2808673.jpg
# img-36-_jpg.rf.95615166c81ee5f5285785d863c7749e.jpg
# img-34-_jpg.rf.bdbab0d1018a6f944807f6cd6bac7002.jpg
# img-27-_jpg.rf.cc8eecdd6bc8ed213a9d90ebae4bd662.jpg
# img-28-_jpg.rf.dbe992c8c840c95608266ce0ba19f592.jpg
# img-35-_jpg.rf.d4796cf0c1bd8a9af02f95fcb18ce449.jpg
# img-31-_jpg.rf.4440045dc42e615de1fefdb87ca63a42.jpg
# img-34-_jpg.rf.6780fab9c503d999c98a59a38f02e9bd.jpg
# img-35-_jpg.rf.f7e409919be41a1e70059b6a5d206496.jpg
# img-29-_jpg.rf.d100297b918ad60fbd844d92d250a410.jpg
# img-38-_jpg.rf.b5a2bf6ddfd064deff86b28f2617318c.jpg
# img-3-_jpg.rf.01c90e1ca6c99ed4a7b8278632f96e76.jpg
# img-3-_jpg.rf.238d6f4b4fdf4e8cf57fd1b178502b2a.jpg
# img-32-_jpg.rf.0895bf5c8577662e99971cbb7159466b.jpg
# img-38-_jpg.rf.e0a5d3daa95549a07e51d070270ee660.jpg
# img-36-_jpg.rf.32e071ec693023d602455ca4d975cbc6.jpg
# img-35-_jpg.rf.a7f7cea62ef2307267d07568f093d543.jpg
# img-42-_jpg.rf.a0987f6fcde8c26253b8819b8aebd42b.jpg
# img-46-_jpg.rf.54e6c542af559c704e3f11d8739ce67e.jpg
# img-48-_jpg.rf.78ed8664fb2652b52373ce7a7eb16173.jpg
# img-45-_jpg.rf.85c55b565b80f6613302c1e410d8c2f0.jpg
# img-41-_jpg.rf.4f7b6329c82ae0a31846163cf2ebc3e1.jpg
# img-40-_jpg.rf.c74e98f24d3fb59eb183b530b567886a.jpg
# img-5-_jpg.rf.50145c6f6892fc43f72a149dbc03f350.jpg
# img-41-_jpg.rf.c527fc63767008fa9506a05ea7b5f4ee.jpg
# img-44-_jpg.rf.dfe80964a4758cd34796a71fe3bfe132.jpg
# img-43-_jpg.rf.0fb7781728a9efbb983fc3b97a6f98ff.jpg
# img-42-_jpg.rf.506b5b9d993824185d8c64ac7e3dc33c.jpg
# img-51-_jpg.rf.392527876c7868ce3a89e10cb4888551.jpg
# img-40-_jpg.rf.54d4976f6d5dae8f0eb06463d22f86a7.jpg
# img-5-_jpg.rf.d3d23bc6d487a8007bee6f89b5cab18f.jpg
# img-46-_jpg.rf.2b9d03452b90e5f39f74c33d0063fd2d.jpg
# img-50-_jpg.rf.bfc3e236d9e6458254ee1331c02b029a.jpg
# img-43-_jpg.rf.d5c14e3f3c9b6903c60568012ece5481.jpg
# img-49-_jpg.rf.ec1b4648ddecec2fed73edfd2da91231.jpg
# img-46-_jpg.rf.db973d56090a27adf3caaf0d3adc1c8f.jpg
# img-50-_jpg.rf.232da9e457f942dfbacba42b05724639.jpg
# img-51-_jpg.rf.65759b4d902d483adaa6154fa24e1cf9.jpg
# img-51-_jpg.rf.1fbf0056696afde4731d67ee024fa69c.jpg
# img-49-_jpg.rf.2bb685a06b3ffc21fffc14337dfac040.jpg
# img-42-_jpg.rf.566956addc532d433a56e483d17ee668.jpg
# img-44-_jpg.rf.2ee60ae14a06362d0fda847bc8f69db7.jpg
# img-45-_jpg.rf.927d99038995303d9db08cd449bd1e0f.jpg
# img-40-_jpg.rf.ae54c31242475982bad3d5d0b653a16a.jpg
# img-39-_jpg.rf.ab8e0c584ee6152354a150c8b3623816.jpg
# img-48-_jpg.rf.cc968f42bb53585769993e4c30e7e59f.jpg
# img-48-_jpg.rf.6d58b0a0dedef9cad723413451236b88.jpg
# img-44-_jpg.rf.53d98abe0a486865531b5505347b3ee2.jpg
# img-43-_jpg.rf.60f166ab77c73a83d991787358e3d323.jpg
# img-41-_jpg.rf.195dfc4ffdf52be0aa3b73bf0e8d1bf0.jpg
# img-50-_jpg.rf.a1f5eb977d42e7e302544dc75cddc5c4.jpg
# img-49-_jpg.rf.811d0ec9de49d93b59dca693c7b2ae4c.jpg
# img-5-_jpg.rf.9ff37b313a030b70d542b564ffbe5294.jpg
# img-45-_jpg.rf.2a9ce5c8cada6ae200c7f8b9dd2eb284.jpg
# img-39-_jpg.rf.972b25722b6524131cca0b40bb9f09e8.jpg
# img-69-_jpg.rf.b3aca2959d5e1fb5d2e1cf4833747293.jpg
# img-64-_jpg.rf.1867b7092522ce08988085186b40f261.jpg
# img-67-_jpg.rf.54ee49557db8a6d857f32cc16fb1de56.jpg
# img-63-_jpg.rf.bf502da5c5bca71daa4c9429588a3164.jpg
# img-62-_jpg.rf.71d2b27cd3122d6eebd44c11e4a37f81.jpg
# img-56-_jpg.rf.6fa85f76a943a0b4330085f23b28fe7d.jpg
# img-64-_jpg.rf.2a7c64151096513245d4304c72fb9a41.jpg
# img-58-_jpg.rf.0ddc473e0c18bf601e1778331ddf8c89.jpg
# img-57-_jpg.rf.e23ffe75ffff711f03d0de2c1247fe2d.jpg
# img-67-_jpg.rf.564e7aa2a73621e553e6f3222f2d2aec.jpg
# img-53-_jpg.rf.f8175eff61aa20eee993810a26f61358.jpg
# img-69-_jpg.rf.17659ccd95c7f1fec624f62ef46f146e.jpg
# img-64-_jpg.rf.b9c6b21a3a59608179718e95517133d1.jpg
# img-58-_jpg.rf.465987c735664d68347f1a1f2b86eb42.jpg
# img-53-_jpg.rf.1de2314fd42e96000e8e02e4b7308a31.jpg
# img-57-_jpg.rf.cd861bdde3661ed8b5310513326976bb.jpg
# img-63-_jpg.rf.38e9592a63675292effebda815c9f356.jpg
# img-69-_jpg.rf.9e366292153721e2aa8db14616041278.jpg
# img-66-_jpg.rf.c75e358d51513277b610b9734467f7fa.jpg
# img-62-_jpg.rf.99330cd59814375dfd198edf18aeb942.jpg
# img-63-_jpg.rf.8f3a18a6d671cec5d4f533a1d5fc8b83.jpg
# img-53-_jpg.rf.28d865b36f9dca9890418f959ad26501.jpg
# img-6-_jpg.rf.74fc73d959b805985b3a231fa97f0fbf.jpg
# img-56-_jpg.rf.19b0ea81c1fedebbf9aa1fa365d3a4a1.jpg
# img-6-_jpg.rf.31bcd2f825d6b8f9318e0f015a58f12c.jpg
# img-67-_jpg.rf.0f63d1b838d2e28e39e7ae4caaf90234.jpg
# img-61-_jpg.rf.649779633f36d0b348de69ec2241e39f.jpg
# img-61-_jpg.rf.6c2288ea648b31e448b96f3d08cf0f78.jpg
# img-56-_jpg.rf.08cfbb158951a0938110c96353000eaa.jpg
# img-66-_jpg.rf.456abbb9ce6d00c8c56d5a8d2f015c7a.jpg
# img-62-_jpg.rf.6acd3e1d715082e21f9af728eecbbd53.jpg
# img-57-_jpg.rf.64c6335b5b6f42cfd2adee1feecc7e91.jpg
# img-66-_jpg.rf.d289e8bba107f4002f263a4c99f14bb4.jpg
# img-6-_jpg.rf.e0f43115ce8b8b0f10a9a66615da2009.jpg
# img-58-_jpg.rf.2ddf1cfe52be1b5b9f7f24ff206a7642.jpg
# img-7-_jpg.rf.21d3a70947fcd45b865fb359d52e0128.jpg
# img-7-_jpg.rf.904bad073ab2c8b5c559fffe2f54bfe5.jpg
# img-61-_jpg.rf.6dea014caec3c7755a6265be69b219e8.jpg
# img-81-_jpg.rf.3989c1abfc21eb54122b275d73444713.jpg
# img-76-_jpg.rf.8176d0965aa1307702e22d5cebc8cf34.jpg
# img-76-_jpg.rf.c1e6c28715b5ecf98857365beed5d929.jpg
# img-77-_jpg.rf.9d2aaed215bb2c8dadeeda63b3722d0e.jpg
# img-74-_jpg.rf.037870390ac1ec988a7329d560fe489e.jpg
# img-7-_jpg.rf.c66507e80e6905583cb31633dd9384d9.jpg
# img-71-_jpg.rf.d0b4549e694709f54e0f6bc5c5ed536e.jpg
# img-71-_jpg.rf.82396faeb8abf7009125badf1dfd1b68.jpg
# img-71-_jpg.rf.b17d8d3354c3ca11cb0558c289c488fb.jpg
# img-84-_jpg.rf.7483822079c553de9cd72f12428e0db0.jpg
# img-83-_jpg.rf.9f0dff021f39da672da2cf69a4527fd9.jpg
# img-72-_jpg.rf.e9d16bc9eb9902f77735284c0cf69422.jpg
# img-77-_jpg.rf.dd56eb56cc10555e64b583db1e2d161d.jpg
# img-8-_jpg.rf.8bcbefd6898d52db73f206b98ed08f82.jpg
# img-77-_jpg.rf.78f9b5851dd12799123a51a6871ac3c2.jpg
# img-72-_jpg.rf.41e81930fe27bb2b6b24312515a539b3.jpg
# img-86-_jpg.rf.50398e81d837bf8d22455a16139cdea1.jpg
# img-74-_jpg.rf.1adb5187b2f00c43cca67fdf4e88f68e.jpg
# img-84-_jpg.rf.3f81f0b8407e0d8bcfffdc2c06fea406.jpg
# img-86-_jpg.rf.362788e6a455f9c3770492dca7730105.jpg
# img-70-_jpg.rf.ea387bd9e88746405815dfdbfa0144f8.jpg
# img-84-_jpg.rf.4f0cfd84fb0956ecda3982aa53877a83.jpg
# img-88-_jpg.rf.0dd81978adcfbdb34591680eb198b9e2.jpg
# img-8-_jpg.rf.c78a9b76a0c662e2a03ec543db963f10.jpg
# img-83-_jpg.rf.92577ea947272926be993b5168d12279.jpg
# img-70-_jpg.rf.385780101313b54ff9fdc15411c42f2e.jpg
# img-81-_jpg.rf.1068d664c6507f89ce1f855b151fd24b.jpg
# img-80-_jpg.rf.2e1fad96c00ecbabd0f141005176625e.jpg
# img-8-_jpg.rf.21baac41ea1321ea0cd635587c6d7710.jpg
# img-74-_jpg.rf.e82e671295de643151cad4f67ece6772.jpg
# img-76-_jpg.rf.dbb59b08e443a41e87167cc84e38c6a9.jpg
# img-70-_jpg.rf.4092f14bdac56a355b68a4ba4a65afca.jpg
# img-81-_jpg.rf.1cabfc6f0ef37a517d313ec65ba149b5.jpg
# img-80-_jpg.rf.1a3356096541b2fb5d75611807c7063e.jpg
# img-83-_jpg.rf.e500917025bfd325f08fb36e44819212.jpg
# img-72-_jpg.rf.d49c8696cb80681905b09ec979c737b3.jpg
# img-80-_jpg.rf.b393bf49afbfb187e411ced4ed8f4dc8.jpg
# img-86-_jpg.rf.d7071a249335dc56e94a7ee208a4c923.jpg
# img-97-_jpg.rf.48db5dee68811dc8e59abd171f3cde8a.jpg
# img-89-_jpg.rf.58328f1b69811100eb887896a6b838f4.jpg
# img-88-_jpg.rf.c9e6b031936e317cd593c26ad5b2343a.jpg
# img-9-_jpg.rf.b36d7241c9fad92213a630a7e1d4f249.jpg
# img-89-_jpg.rf.c4401fc71a786c9184ee824b7a8a9834.jpg
# img-98-_jpg.rf.f763b9715a4ce81db1c40ac2640d0162.jpg
# incendiu-acoperis_jpg.rf.70443f2864b46918f7589d2383d17371.jpg
# img-97-_jpg.rf.008f22f0173dc0070cd9ff757de4f47b.jpg
# incendiu-acoperis_jpg.rf.3a5c0626834b9013b9b298fe2f627e36.jpg
# img-96-_jpg.rf.72e76011b1e3d14c987bf6a03786e17f.jpg
# img-88-_jpg.rf.a9b598c0778e55a1348f58eb45163797.jpg
# img-95-_jpg.rf.0dcb172a0fa7fa1ff8ae4d633e86f462.jpg
# img-98-_jpg.rf.04e6276b8628f6833c30ef29f0d8ee97.jpg
# img-9-_jpg.rf.b4516eb597242d6a0d8ec5c50830d9cb.jpg
# img-95-_jpg.rf.e2443881c83d30107c14d7b4bcb88c1e.jpg
# img-93-_jpg.rf.26e433c71d4b9e5a61ab7188854dc581.jpg
# img-92-_jpg.rf.1012264d366cc9c0b44dc923ac245ff5.jpg
# img-91-_jpg.rf.a986d9862d473d0ade6d08eff13146ba.jpg
# img-94-_jpg.rf.7b41b6f2ea8787abbe21361e575fb0f6.jpg
# img-9-_jpg.rf.7931a83aeeb6b698ab429bb5d6812aea.jpg
# img-94-_jpg.rf.9c4563788b420d7041a1d371055f519b.jpg
# img-95-_jpg.rf.9ad7f4744d1b4dcfc703d2adbc3c4efd.jpg
# img-90-_jpg.rf.52678c3dbb0c7941ad39e698c88add1d.jpg
# img-98-_jpg.rf.e04bc54d8d7eaa0cc65cdb3d7245528f.jpg
# img-91-_jpg.rf.2002c807b9eda4578f11045c6ab6d9ec.jpg
# img-90-_jpg.rf.4dc7c4053af1cb790cb46e9ba77f4b2e.jpg
# img-92-_jpg.rf.9cf45c06cf1add734d169a14f4ba9f06.jpg
# img-93-_jpg.rf.a6bd254d7ee3f435b8a14d92de2d95ec.jpg
# img-96-_jpg.rf.fd38089b436298bacc3cb32522345a1f.jpg
# img-96-_jpg.rf.eaaefeb4cad07eb0517886ee1efa8080.jpg
# img-93-_jpg.rf.6fa8ba91f31af7a9fa4b58ec946d95dd.jpg
# img-94-_jpg.rf.7ee47797cdbba11933cd1cef4bff5815.jpg
# img-92-_jpg.rf.db0c42c97218115f22b6fcbda25f1abe.jpg
# img-90-_jpg.rf.635e5c847e1e6fa8e406d6c3694158c7.jpg
# img-91-_jpg.rf.1fe2434d290a7eb127682d7a86918565.jpg
# img-97-_jpg.rf.343dd7feb3f8c2a686dbe3a159c87d47.jpg
# img-89-_jpg.rf.871c7291786c8bd7660cfc24a5ff189e.jpg
# pic-107-_jpg.rf.28b6ac359d604101c7a52abd3a8358ab.jpg
# maxresdefault23_jpg.rf.b0b0b3804a0948c73bad91282c077765.jpg
# pic-101-_jpg.rf.b4ce72a8a2576f1b4d5cf44bd3484dd1.jpg
# maxresdefault23_jpg.rf.161f84146aec1462913185298abca991.jpg
# mfs_fire_investigation_image_bedroom_with_candles_2_jpg.rf.946ed98d6d52f4dcc6bfc573ea643d77.jpg
# maxresdefault6_jpg.rf.428bb6a819aa7da26b350af888c274bc.jpg
# kjlkmnjkl-_jpg.rf.a1487de4aa49ee1b8baffd4e24fe5e39.jpg
# pic-103-_jpg.rf.2e1819947679def84a05dfc26e957cd9.jpg
# maxresdefault_jpg.rf.424e9126e901b41535e587f134e11c87.jpg
# o-WASHINGTON-FIRE-900_jpg.rf.4835a7292fa988f9648768657268c22b.jpg
# kjlkmnjkl-_jpg.rf.65b7c6c809d534b5e4491f192368eb41.jpg
# maxresdefault24_jpg.rf.2e4fc05a2fa9175f2a84fc3d1f78a593.jpg
# pic-101-_jpg.rf.a1e70ec3de0893072590459e3f5ce2d3.jpg
# maxresdefault24_jpg.rf.3c75439622a0132445f5f074cd63dddd.jpg
# pic-107-_jpg.rf.d26ce66c7cacd9120fe027ef7b79982b.jpg
# pic-103-_jpg.rf.a5f970393b88d0d842c34da09254c614.jpg
# pic-101-_jpg.rf.cc9d3e537a7d75a13b377c1b0797eafa.jpg
# pic-105-_jpg.rf.790bb301056e72dcf843da54bdbda592.jpg
# maxresdefault_jpg.rf.10c777be49c1f386761949dc40623a50.jpg
# maxresdefault24_jpg.rf.7eeb60dadfd51703879211d3027e1bcf.jpg
# mfs_fire_investigation_image_bedroom_with_candles_2_jpg.rf.e942eba532fa1f81fc46657ab3dbcf5a.jpg
# incendiu-acoperis_jpg.rf.b7991f2c8f590b2af947de2c7885549b.jpg
# mfs_fire_investigation_image_bedroom_with_candles_2_jpg.rf.c5abd81c2d4ad98fd8f3b3f16b40727e.jpg
# maxresdefault6_jpg.rf.5b6782d5a42ea2e6b038b290d986731d.jpg
# pic-109-_jpg.rf.1b4be8286ec307517d3a5870add5d323.jpg
# pic-100-_jpg.rf.8b72b93e4e60844ac87969142c48ae46.jpg
# pic-103-_jpg.rf.b958e7972a1ddae0de7930ea6d24d02c.jpg
# maxresdefault_jpg.rf.ca1ac1dd0e6a86b279be73dfb1bd31a0.jpg
# pic-105-_jpg.rf.f75eb2fcdcb64d3aaa50c08d6154a449.jpg
# o-WASHINGTON-FIRE-900_jpg.rf.a59099ea02108eda7924d880b6557147.jpg
# maxresdefault23_jpg.rf.c38d69a961535378f7e0ece401043c04.jpg
# kjlkmnjkl-_jpg.rf.93998022f095cde1e1db119a586701a6.jpg
# pic-100-_jpg.rf.1cab5b936a2c8820c14f0160e6f3ff4d.jpg
# pic-107-_jpg.rf.0c14edac70fd6201a95a7b70f3de4b0a.jpg
# o-WASHINGTON-FIRE-900_jpg.rf.3ad2d8f896cd3c1101ce08690eecb8cf.jpg
# pic-105-_jpg.rf.01c6eac0aa50f1e34620964dd1f71b7c.jpg
# maxresdefault6_jpg.rf.3d0241aa7645b169d99ef299ac7edf0e.jpg
# pic-100-_jpg.rf.0291bb7d1d410374909be182d1769875.jpg
# pic-114-_jpg.rf.f1949905bec8a3d168de1593246fc69c.jpg
# pic-111-_jpg.rf.63c6a99739e128c1e1cd2374818b5f57.jpg
# pic-116-_jpg.rf.82deeac29217ee4a164eb097433c8616.jpg
# pic-118-_jpg.rf.1867bb957963ccd73aec734a29130eba.jpg
# pic-113-_jpg.rf.99f713577d653e2198a87abc8c1653c7.jpg
# pic-121-_jpg.rf.e346983ccb21ff18fb296052b0f5a131.jpg
# pic-114-_jpg.rf.b59f15a0c4891d488d3eab1666597e68.jpg
# pic-123-_jpg.rf.bb94192f16b80dd0eea5f0689d642144.jpg
# pic-109-_jpg.rf.d829f95bb122ecb155c319b02816f1a9.jpg
# pic-11-_jpg.rf.7e1a7aec133a7e7bb25036fb2ccca51b.jpg
# pic-116-_jpg.rf.d67a06feda0e8a1d0d9cca0cfee24cf8.jpg
# pic-112-_jpg.rf.cf72a372ea1f2b092e343e910babde44.jpg
# pic-113-_jpg.rf.f0c968847ce627ee575274ed2a072fa0.jpg
# pic-122-_jpg.rf.201a8d424fa44ae96f4a6b64b1487593.jpg
# pic-11-_jpg.rf.15ac9a7b269e2af189b750bfbf497782.jpg
# pic-121-_jpg.rf.da67c9ba9b787f4416c1ca21d56fabd6.jpg
# pic-119-_jpg.rf.42d1accaab9ead26a02196d64b54fbe2.jpg
# pic-124-_jpg.rf.32a3adb66a33264b96529eb7a6a73855.jpg
# pic-112-_jpg.rf.22553a56e31447441529cb4858324229.jpg
# pic-122-_jpg.rf.d71b28fa4cc5b060fea2ea0acd0784dd.jpg
# pic-123-_jpg.rf.9949ea2903852117c0ad1ea125027258.jpg
# pic-109-_jpg.rf.548c793cb7a7fadfae2811f757729187.jpg
# pic-111-_jpg.rf.24224540853ac800c00cb31a784c0870.jpg
# pic-113-_jpg.rf.893a15b60a4459528b839107075982c5.jpg
# pic-119-_jpg.rf.a851181050e34fab6d1a8eb5732fd0b7.jpg
# pic-119-_jpg.rf.15e2e9f7fd8885f44be3afd39f00ab63.jpg
# pic-118-_jpg.rf.ddf06c591590bb51d6123929066deb16.jpg
# pic-124-_jpg.rf.cf6e593e8b957fe30c463c7f8e36a69a.jpg
# pic-11-_jpg.rf.657d850c6a0454e8b447c326f9a1f262.jpg
# pic-112-_jpg.rf.f7ef8aa7df0cf6df7aaf6e2658ec2ed2.jpg
# pic-121-_jpg.rf.34e6282e256a02c6e231f68b53e3e903.jpg
# pic-118-_jpg.rf.5a56d8ad55d5adc27f6f515d71f3f792.jpg
# pic-123-_jpg.rf.4e13176db705561c689a2e26c2c55fe1.jpg
# pic-114-_jpg.rf.d8d075720c0c268388146ccfa551ad05.jpg
# pic-111-_jpg.rf.f5d9ace5f71bac04c4904d095331fc4d.jpg
# pic-124-_jpg.rf.17cf7edfc0a4ad339ad5b23b0aff3e38.jpg
# pic-116-_jpg.rf.831153e2ceea8879bb2348c3e18d7a71.jpg
# pic-122-_jpg.rf.22d34008682346ae5000c12ebc1bbc3d.jpg
# pic-135-_jpg.rf.05d2f0e961d14e8a14006c6d33298fd1.jpg
# pic-138-_jpg.rf.4e4b9f6ebbf753421ec576e5828ad5e0.jpg
# pic-128-_jpg.rf.eb33a72c659ef57b7e3f659c6d79ed9c.jpg
# pic-135-_jpg.rf.0679d108a629a5215f569a6941425aaf.jpg
# pic-126-_jpg.rf.90a0cfb1bde9e941696cdcd325116b57.jpg
# pic-135-_jpg.rf.6ff5d64f2393c4ed77b69e77e8881f24.jpg
# pic-129-_jpg.rf.c15693bd296d617772a748881d330284.jpg
# pic-137-_jpg.rf.bd216b72788d380ef215d9dca6745fcb.jpg
# pic-136-_jpg.rf.8af7dccafd61a7bc172a984f8074401d.jpg
# pic-129-_jpg.rf.2c9d52dd5f53a0eac1944c4c30462943.jpg
# pic-132-_jpg.rf.69545ab8da06130deea9b7899273790b.jpg
# pic-131-_jpg.rf.fe979e5cf5f3b8a275c8de80da7bd5e3.jpg
# pic-13-_jpg.rf.d6cbf4bfe8cbe393aa70655d910a2fab.jpg
# pic-126-_jpg.rf.d8d8606392a52cd694cd1c89f6d47e29.jpg
# pic-125-_jpg.rf.49f3c90dc49bec72e52c5e76fd075428.jpg
# pic-133-_jpg.rf.f8ec8eb5a2f44701fbb042c90addab1a.jpg
# pic-129-_jpg.rf.d832be07d1bd9ad94019b1f5962b1722.jpg
# pic-126-_jpg.rf.9ca3e2b42f5bf967011d12a56dc05607.jpg
# pic-13-_jpg.rf.64748d29790e69345d513cfc2ba7cf5b.jpg
# pic-137-_jpg.rf.47c7db3ec497fb9fb2109bf58d760ab0.jpg
# pic-136-_jpg.rf.827e016db10f5003295edade41409354.jpg
# pic-128-_jpg.rf.3cb7b9131de270e4a04a5b172a5a129f.jpg
# pic-133-_jpg.rf.bffe7e201313c6b2f37014296f28f427.jpg
# pic-136-_jpg.rf.693383cc550ae1b35f16080a93857748.jpg
# pic-125-_jpg.rf.04eafc0e5391255c9597b6cc89f3aae7.jpg
# pic-133-_jpg.rf.747e6382407b47ebb1e31480362e471b.jpg
# pic-128-_jpg.rf.be5141bc398417cf833d588882ca1e25.jpg
# pic-131-_jpg.rf.f3cd42715a7a18e34cec2e5a189730d5.jpg
# pic-137-_jpg.rf.6687e05edef260f65c5b74ebca8d9f9d.jpg
# pic-132-_jpg.rf.080aa4406ae8ef80f4c9fce3ef978bda.jpg
# pic-134-_jpg.rf.cfa3035858e6c37d6c3af0d42d59b699.jpg
# pic-132-_jpg.rf.48ef21f77df1d35de110794af22b7986.jpg
# pic-125-_jpg.rf.9835e03f9bb6d8a9b0dfae7a795d4d65.jpg
# pic-134-_jpg.rf.25e53ff44693f04a104f4f731a07c7fd.jpg
# pic-131-_jpg.rf.672ba3c8a0a25c20288c1d79707665c6.jpg
# pic-134-_jpg.rf.5a23a9909f198b5909bad3d42f86e37e.jpg
# pic-13-_jpg.rf.0f65ba62c3a56fbd8446e48c90acb217.jpg
# pic-142-_jpg.rf.ee8c1e28914a7a9abf0f730b3d39cd7b.jpg
# pic-145-_jpg.rf.f16678186d983b6ead42d11bb09d8420.jpg
# pic-146-_jpg.rf.10975ca7fafebd4c962b0e332357dd58.jpg
# pic-143-_jpg.rf.e60c632f4ecd30a859278b4b4513b9a5.jpg
# pic-139-_jpg.rf.1dcb08923990066b0ac89e776a167776.jpg
# pic-140-_jpg.rf.c5abc97d27166cad786568a586faf7e5.jpg
# pic-144-_jpg.rf.29612b396029591dae1dc7ea84ee2c79.jpg
# pic-15-_jpg.rf.9d051e01188fbd6e0cd7059f16b936de.jpg
# pic-147-_jpg.rf.0f72bd3d23764f3564bdc4ecf44ffa66.jpg
# pic-146-_jpg.rf.1d0cb8bb466fcecf5069069de558c8a1.jpg
# pic-147-_jpg.rf.38a16dad4461cbf09f2a735e66b5bfed.jpg
# pic-149-_jpg.rf.53eefdb1b5f53861081d1c6b8a4aaafa.jpg
# pic-139-_jpg.rf.d668316e44236485a0028edf30bed6f5.jpg
# pic-14-_jpg.rf.59d0b7a13e736d6ed97cdfbdad4d21e1.jpg
# pic-15-_jpg.rf.94f9cecc37a696b3de955c0094f96779.jpg
# pic-150-_jpg.rf.6f0bdaccff475232f2660b0866fbb897.jpg
# pic-142-_jpg.rf.bcc06d1db6c8ada7e2fe9213581535ed.jpg
# pic-140-_jpg.rf.c2d30cdb2e6570fc4f94b04bc78a7024.jpg
# pic-149-_jpg.rf.ff10a9fa83a07f4e1409de48292c5a5b.jpg
# pic-15-_jpg.rf.9248fd78ec02a0ccfa6aa9e8c4c73a67.jpg
# pic-14-_jpg.rf.b614279283e5b8d9a1155b1e02b61ebb.jpg
# pic-138-_jpg.rf.b49ea315d0a6310938435b630b3e6e89.jpg
# pic-146-_jpg.rf.105ca71da995a72245ed3d020e2364ad.jpg
# pic-145-_jpg.rf.2f9a43f55621405d3bcad1e103818403.jpg
# pic-145-_jpg.rf.338c9364ad799eb34742d3fa1bcb6f26.jpg
# pic-144-_jpg.rf.f5f15f76bccbd440f960c06788a65354.jpg
# pic-147-_jpg.rf.91aa9924aa6119c7e4e63056c696f27b.jpg
# pic-150-_jpg.rf.372ec2e6d80685116dd899f62ccff734.jpg
# pic-143-_jpg.rf.31a6e64a5f82a775b3caafd15be154b9.jpg
# pic-140-_jpg.rf.34bf41478eaf28dfd2ddac06cca45ede.jpg
# pic-143-_jpg.rf.ace4afcbe0a4876ee41f8fb1cbc46d83.jpg
# pic-149-_jpg.rf.0228dcf03b64fe69185acaca87fa9b6b.jpg
# pic-142-_jpg.rf.9b6295eceabae9fe732bff3d97cde666.jpg
# pic-139-_jpg.rf.47dc227e69f223edd77663cadda4fd8c.jpg
# pic-14-_jpg.rf.53db2a6ac6969556316931ed3336df36.jpg
# pic-144-_jpg.rf.c76f4d87636ce735e46a5102bbd44134.jpg
# pic-138-_jpg.rf.b53e2e4cc8e9806c90c1568c3689afde.jpg
# pic-164-_jpg.rf.ef00dba0b90df204dea7aa5628a4f4c3.jpg
# pic-156-_jpg.rf.a2fa08fd6d6de8d3cca058444b2eb7de.jpg
# pic-162-_jpg.rf.0a059abdb79140bdc03602a105d4d92e.jpg
# pic-16-_jpg.rf.6b42061e6c7f4dd8735554fa93b1e84a.jpg
# pic-166-_jpg.rf.24d65d18085015564a246e25fd74ef52.jpg
# pic-152-_jpg.rf.cd66c7576a0d1ac86f228b0bfd63bd55.jpg
# pic-153-_jpg.rf.05896cf3340bd5a96ca69776dc424de4.jpg
# pic-152-_jpg.rf.c1784e8a8aa613fc2bf0885c4ccb194d.jpg
# pic-157-_jpg.rf.49c3d7ad72ba12936009b3aa01f43f47.jpg
# pic-160-_jpg.rf.fc5f714de86cb9fea8d952a323896558.jpg
# pic-164-_jpg.rf.7d791d36529e3666c14a0fc328a9643d.jpg
# pic-162-_jpg.rf.8d6a2aee28ee1cdccc358247cdfd308b.jpg
# pic-154-_jpg.rf.3a4921f21035b46b6c7370717844da43.jpg
# pic-16-_jpg.rf.3dbe95606bef3107897b03fdd50e83ac.jpg
# pic-160-_jpg.rf.fb03e69e50d422d24f24bb93fcde97f2.jpg
# pic-163-_jpg.rf.0fb4833f25f27aa50f2ae7ac5eb207f2.jpg
# pic-159-_jpg.rf.2f979116ad18d0aecf966e30874e3a43.jpg
# pic-151-_jpg.rf.a2624cd86a85ecc575f859d2c07264a9.jpg
# pic-163-_jpg.rf.af13290b801e13a04abc32c34481399a.jpg
# pic-164-_jpg.rf.6ca9918a7cefa1b7637f1ea373358123.jpg
# pic-159-_jpg.rf.09f395cba1f6a9a3f545bc338f12e714.jpg
# pic-154-_jpg.rf.870a775048c63e3c871ff45c8ff80115.jpg
# pic-159-_jpg.rf.6871bfef1ce0791184eee2f35f65950e.jpg
# pic-156-_jpg.rf.2fc8ca11864108265b1d33769323b81b.jpg
# pic-157-_jpg.rf.0cddb6a0611028eb1b582fc19f8f8fc1.jpg
# pic-151-_jpg.rf.b26ba78aa70d204a67829e08a3a64ac1.jpg
# pic-166-_jpg.rf.66efea53cefa926592f80d6200f01d69.jpg
# pic-151-_jpg.rf.cc30ce293f59fb37f5e429529558d245.jpg
# pic-154-_jpg.rf.f4027705df696fc5a77cc19c98764a30.jpg
# pic-163-_jpg.rf.cd55ce0aa4c329e9ebf176e5afa560cb.jpg
# pic-153-_jpg.rf.6b2a0eb1934e8aabdc6f5ebe03d07d43.jpg
# pic-16-_jpg.rf.a42d8006a514b3d2c5048e48b7d4c07b.jpg
# pic-150-_jpg.rf.a09e837d408b7275435e0bc02f5222fb.jpg
# pic-156-_jpg.rf.4e0431a24e08adc51a433fd89b83b24e.jpg
# pic-162-_jpg.rf.6976c4eaca058098e314cc380abb70b6.jpg
# pic-153-_jpg.rf.c4c35d39ee257d1e680df683060af5d8.jpg
# pic-157-_jpg.rf.8ec37a91833a6bc357756de4c599a0cd.jpg
# pic-160-_jpg.rf.430a4f3e813bcd429f1a448b77b46a3a.jpg
# pic-152-_jpg.rf.2bd232d586dab09935f02a2b9ecf835f.jpg
# pic-170-_jpg.rf.a5167b5a99196f7cb22bacbc7d06f7f2.jpg
# pic-175-_jpg.rf.a39d44febeca63590a8f00a8323a3b3b.jpg
# pic-169-_jpg.rf.64de4ba5031a9296d811c077c6d099b0.jpg
# pic-179-_jpg.rf.d72cf1504d9b635c64ae874c206c4f54.jpg
# pic-166-_jpg.rf.cd195caea971cb93dc216477e409fbf0.jpg
# pic-181-_jpg.rf.e61deeb52036f037aa0583be429fbed7.jpg
# pic-181-_jpg.rf.0128d3de55c2cf1a1d0199781b009c8b.jpg
# pic-177-_jpg.rf.71ba92356ff950d7a57bbc09b3497a66.jpg
# pic-174-_jpg.rf.8c6af2eb39b60285f96ca27187e95c55.jpg
# pic-17-_jpg.rf.99831e7e3f1a1d75301b508e4f1f4905.jpg
# pic-170-_jpg.rf.aac9f11aaf94491b7a663b2897e9e817.jpg
# pic-175-_jpg.rf.788f9b5338a5c53b84e1771b125d5104.jpg
# pic-177-_jpg.rf.f53edc3a06ba65b6273d0b69c98083dc.jpg
# pic-175-_jpg.rf.1d4aa0a04030112e4615bd7841aecd8c.jpg
# pic-17-_jpg.rf.593a3e1654806aafa3c092a48e8bd98f.jpg
# pic-178-_jpg.rf.a92adbf2a9b2fae6976c5f80fbefe2f3.jpg
# pic-171-_jpg.rf.4351c2cd0bdf567dea067227df79a7d5.jpg
# pic-174-_jpg.rf.7649c789ea9908a7a0b5f91f9fafe69b.jpg
# pic-178-_jpg.rf.609ea4ebbc49024c351a0c80a6eeee9a.jpg
# pic-18-_jpg.rf.385b10daed931e8c20c9d80815741a78.jpg
# pic-180-_jpg.rf.99284f3e623eb0b0a333be8fe43832c5.jpg
# pic-178-_jpg.rf.4cc0bb3d69a55092beb18bff5cff42b2.jpg
# pic-179-_jpg.rf.cda1b43457b489d959801e9e8cf601f8.jpg
# pic-18-_jpg.rf.a7a9bf00972e263006220164c163d2c2.jpg
# pic-18-_jpg.rf.ccde8a1c1d2548a2db1e0cdece597fe2.jpg
# pic-181-_jpg.rf.77c197f30b83d063271a53f8994e788a.jpg
# pic-180-_jpg.rf.bf2b1d17e3eee57e249d6992307f175d.jpg
# pic-17-_jpg.rf.fc7ee7843c66e09fbe3fc40b15ce0f58.jpg
# pic-169-_jpg.rf.97143f2f41a36cee1f98a9894e421c4b.jpg
# pic-177-_jpg.rf.90c0c11360f0eb4ff748d54a0ffa32a7.jpg
# pic-169-_jpg.rf.5eea43125ff02af72efde3b4539127fa.jpg
# pic-180-_jpg.rf.de0ef9fde5f36e3142d5b748c6836725.jpg
# pic-171-_jpg.rf.478e73a0575ae6ebae3341d84a957ba0.jpg
# pic-171-_jpg.rf.5c2adf77242b21c827c0989be2bb792b.jpg
# pic-174-_jpg.rf.1480324e37c04745441251b575ec4eb5.jpg
# pic-179-_jpg.rf.f5e9785a713ce19599ace5c28cdc9e4d.jpg
# pic-182-_jpg.rf.313c64c2b198740185cda95e7428eae6.jpg
# pic-170-_jpg.rf.490572019a21e68b7a195e7a39f1610d.jpg
# pic-187-_jpg.rf.e2f6078145b129b6e6bcce832286ec19.jpg
# pic-190-_jpg.rf.2dbedf313c9cd13561d6ddb31069a300.jpg
# pic-202-_jpg.rf.cd430fee81f783a5ad254283d243ea17.jpg
# pic-2-_jpg.rf.a48cae0ef0fac58e4865b22f4b663502.jpg
# pic-202-_jpg.rf.4db8b0daab70e049411f6c5ec56b6dec.jpg
# pic-192-_jpg.rf.94555f92ecea6bc78c044a97f0ddee9a.jpg
# pic-191-_jpg.rf.ccb55ff2f1c50645acf391f3155dedaf.jpg
# pic-191-_jpg.rf.9c7702f2b868c15cdae74e958f7295cd.jpg
# pic-189-_jpg.rf.9c7abffd6ac1914ea8e7626ee42e2e2f.jpg
# pic-194-_jpg.rf.ca4eac68e7f4194965e832829a2377fc.jpg
# pic-185-_jpg.rf.dac68649890ce80d3aa4464dd83fe822.jpg
# pic-2-_jpg.rf.9de551f8d340a711a26c37543ea14a45.jpg
# pic-203-_jpg.rf.081d1c9b3baa0bbe99cec9ab4b36486b.jpg
# pic-196-_jpg.rf.095b9dbe9dfeb248ab0f66eeab3b188f.jpg
# pic-193-_jpg.rf.a1822e86ec466715f44a1cbae43c0a3c.jpg
# pic-185-_jpg.rf.0b74cf26a73b50db67fa24ab78194d5d.jpg
# pic-182-_jpg.rf.d41e412bef91cfc74e2810d621221112.jpg
# ...
# 1_39_jpg.rf.71fa887a8182fb7dea631eeb7466b1ae.jpg
# 1_51_jpg.rf.1d2de99b57262586684464d7d2e8f6ab.jpg
# 1_49_jpg.rf.36bc5ea2f46487e3035eb8b5eb816f3b.jpg
# 1_39_jpg.rf.c3a3e730b9a3d03f8a2bbc82f06d7bfe.jpg
# 1_37_jpg.rf.9ea8dd37e64fb229ce71b98d11b87354.jpg
# 1_41_jpg.rf.51021b898a2772eaed08891fec7f22c4.jpg
# 1_50_jpg.rf.0df4ba4e3864d3f7ccc715d91186f2fe.jpg
# 1_44_jpg.rf.1da3a32b838f28d5427ed6b682f522f7.jpg
# 1_51_jpg.rf.fb8a6a0da9ce0e6c6bc7f1ab6f33727b.jpg
# 1_4_jpg.rf.4483f80c417fa6f818aa3a7c7d7b881e.jpg
# 1_55_jpg.rf.aa2b702d3fdd0e1faed27719d85b9b8f.jpg
# 1_4_jpg.rf.3ac8cc84d0febd0be9be3adf97dd1aaa.jpg
# 1_43_jpg.rf.4db10fe2039f4a90bf1c3f76932211c9.jpg
# 1_48_jpg.rf.a67e8ff608895c34c4d70a08757bfa6d.jpg
# 1_48_jpg.rf.f34217ba1030d2507037da669f07e540.jpg
# 1_43_jpg.rf.b462f3a3b4d02057b3eb01b268123987.jpg
# 1_3_jpg.rf.5b25f15370492f1030e9b8b77f8fe20e.jpg
# 1_4_jpg.rf.0ae89999ebc86538f92fe32cc3be7468.jpg
# 1_50_jpg.rf.38ef88ea38c443bb9598f4e88b804dfe.jpg
# 1_51_jpg.rf.0449e9526b9305b8e25edc5a5d0aeb91.jpg
# 1_41_jpg.rf.c90ea759e1da30ecb9c586c201df1632.jpg
# 1_49_jpg.rf.d8b1bd8049da403935d3063e1132ddde.jpg
# 1_41_jpg.rf.0837520b0c12ecc098071b4df72f0cd9.jpg
# 1_50_jpg.rf.6cd127f1057d02361afc9754164c78db.jpg
# 1_39_jpg.rf.d9a5f92ef97c275fa50f78712bd6dc5a.jpg
# 1_3_jpg.rf.020ec4603b08a34f388ff59e86688e2c.jpg
# 1_44_jpg.rf.3b02ab6a9a3fe71e59dcf44b62888c6e.jpg
# 1_55_jpg.rf.1a203523e88659b85b634686e51fa96d.jpg
# 1_49_jpg.rf.6509e561ac6b821f5b7fbeac0ecd2380.jpg
# 1_37_jpg.rf.8c59be19dac4c999ab6a212b78f99679.jpg
# 1_43_jpg.rf.e4718c5dbfa25e2c1ec7361c151e0143.jpg
# 1_44_jpg.rf.11345b85ccfcee0a128032d1fa6437bd.jpg
# 1_74_jpg.rf.7901940f6c51283f579937e11db71845.jpg
# 1_6_jpg.rf.b95df9ba144ddabf25bd68d4d4577b56.jpg
# 1_64_jpg.rf.7cd71bba580c37acba4afc867b513ebc.jpg
# 1_74_jpg.rf.ca9df70430aebeeca42f7dcd93dbea4b.jpg
# 1_60_jpg.rf.e2ca004e3e2b613c858cc828818732f3.jpg
# 1_66_jpg.rf.74848346984eb90e02cf3c67ab9e3719.jpg
# 1_75_jpg.rf.dbfded47a7828fba1c1ccc2d64caf8fe.jpg
# 1_64_jpg.rf.8d572a4cadf25aff3dbc2894a55e1e1d.jpg
# 1_60_jpg.rf.77e813c82986c6e3f100f905c87e0ac6.jpg
# 1_75_jpg.rf.3e7a2e13551d439b4ec69fc3a8e86c9e.jpg
# 1_74_jpg.rf.3deea780e41babef352d1c99eeb25fcc.jpg
# 1_62_jpg.rf.67006846dd07c2066119fa4e434d1965.jpg
# 1_75_jpg.rf.2d1dcab354fbaa9efe9c5ab2af477edf.jpg
# 1_66_jpg.rf.3d500b1d4a47d4631271364417b24ca9.jpg
# 1_63_jpg.rf.e5ecfc52db971051426f6569acbc2c76.jpg
# 1_6_jpg.rf.583f28ea8f409cf97172cf330a191c9f.jpg
# 1_76_jpg.rf.0630b584b3215b203d3d5df8417791a3.jpg
# 1_66_jpg.rf.571c33f06cd0a8c9945169903b081fca.jpg
# 1_61_jpg.rf.18882923f1dcd75bd62ba51f13b424cc.jpg
# 1_55_jpg.rf.e393ff4146b8ae29ac861d43803e1e0e.jpg
# 1_7_jpg.rf.b48bc899c88359e9f2859609da8f0fba.jpg
# 1_64_jpg.rf.91c130abff50c0e438642cece399d81e.jpg
# 1_62_jpg.rf.c97fcc48ba395b518f528f13adc9bdc5.jpg
# 1_63_jpg.rf.159d4b6b6a82a5399797da4e64efdadf.jpg
# 1_60_jpg.rf.cf50c4db9745a054a29605245c03728a.jpg
# 1_56_jpg.rf.83821e3276a245e0d73e15910ae7064f.jpg
# 1_7_jpg.rf.c2f637f2b710cdd228002789a6171809.jpg
# 1_76_jpg.rf.097830558d52e89cc29f3f7a1667cf21.jpg
# 1_63_jpg.rf.397d4867ce1e0c37035f6e2cb862f35d.jpg
# 1_62_jpg.rf.e1fb278bc05758b0963485da5b97bd59.jpg
# 1_61_jpg.rf.8ba8031c464e414486b169febca5de74.jpg
# 1_7_jpg.rf.4247eafcd4d7f4ffe20fedb5120255af.jpg
# 1_61_jpg.rf.c0f84322c956df640920cb5449dd42b6.jpg
# 1_76_jpg.rf.cc180378c641fa6c6c9d0ac85a43b705.jpg
# 1_6_jpg.rf.a636debf1bc35781260e2511b8b29c2b.jpg
# 1_80_jpg.rf.2878340ec5fecbad47bd955c1742b636.jpg
# 1_56_jpg.rf.2e40a6daf12ed261a90eb6ed1f9ed015.jpg
# 1_56_jpg.rf.4b610f39db4452ffc4734db7f5535e4f.jpg
# 1_88_jpg.rf.4aa5cfd2ed6537173ab6496668f082cc.jpg
# 1_84_jpg.rf.82433de5aef03a55b76a47bd3fb669cb.jpg
# 1_89_jpg.rf.68c02e4a61bcfbd952bf517d448f8ca3.jpg
# 1_93_jpg.rf.ee9599aa57ac20cfc0f8244e1d5ecce0.jpg
# 1_83_jpg.rf.23ae5434a32f71d2eab2dde473f861f0.jpg
# 1_82_jpg.rf.ec5e18fe07453b0bcba8ca1d04785485.jpg
# 1_91_jpg.rf.11d020c9863e1eb0a5dd203b252286e6.jpg
# 1_97_jpg.rf.74b126d84094d700c1555ead18babb55.jpg
# 1_93_jpg.rf.c5b09c67ded6dc016e128ff3d8b99da2.jpg
# 1_80_jpg.rf.e24cffe1711fefc85f2ea37e25eba0ed.jpg
# 1_82_jpg.rf.dbb1d0f3682afe931c5dcc19b30bec0b.jpg
# 1_94_jpg.rf.62794a5e3478007fe85a09cf8f440919.jpg
# 1_8_jpg.rf.6e1abc91e08b966951b4398a5d6fa460.jpg
# 1_89_jpg.rf.b048e74b5ee32aa5b7c2ad6d87559a47.jpg
# 1_92_jpg.rf.b8f2fbd976eac7f3b433a2e9bc2bf493.jpg
# 1_84_jpg.rf.b02086fe02a21481b60cca7773236801.jpg
# 1_94_jpg.rf.5d97c36317be88b1c0ac5fd6ab679ff4.jpg
# 1_89_jpg.rf.0d1534858a372451c3ed312aab58fb79.jpg
# 1_83_jpg.rf.84992636ac17297fad3afe5bb37ca3ba.jpg
# 1_91_jpg.rf.6ec6ea71d2f3b543ecbc1b62ff19d843.jpg
# 1_8_jpg.rf.31b7626f1b2f842d9c1e56e693381618.jpg
# 1_8_jpg.rf.7a7fb931431d3dec6e30767e7e8b236f.jpg
# 1_91_jpg.rf.01c2bdea9c0c54db7691ac19aa7836c0.jpg
# 1_88_jpg.rf.132841096cd6e93a2ffc4bcc60b4f3ff.jpg
# 1_93_jpg.rf.b00f489f82beed074c4fce38024f824b.jpg
# 1_83_jpg.rf.f303b2eeecd2ec718a103798a6c985b8.jpg
# 1_92_jpg.rf.72112ec237469da446eec4d603defdfb.jpg
# 1_95_jpg.rf.fced9962b4f265f9725dd0602d264af6.jpg
# 1_82_jpg.rf.20ff1536d85fe97e9968b138b2a721d4.jpg
# 1_88_jpg.rf.307c26cc7c230a6487c94b7be4c347d9.jpg
# 1_92_jpg.rf.b00cf94fcf7832565d6bbcef78e02a54.jpg
# 1_94_jpg.rf.c07c34d6bb3ef4b4cd15ed78415fbc3d.jpg
# 1_84_jpg.rf.6645a81cc566d9bc97c38d070acd2a58.jpg
# 1_95_jpg.rf.f638f6318b4fcbe17531b872e0b3cc9c.jpg
# 1_95_jpg.rf.af2d14998c1948229f8a66e1c488cfc2.jpg
# 1_80_jpg.rf.bf9eccf31c522f4b9b6f09bb41523574.jpg
# 1caa69fb-f2f3-4cae-a5ec-cf51c73dc970_jpg.rf.136abc4b391601fa2e368dcfbf36b478.jpg
# 1c8480e0-7f02-412e-bdf4-bea8ca79d7ff_jpg.rf.9a913819ee83ac32759527475d7aafe0.jpg
# 1_97_jpg.rf.92da97757b668f89aa1958251b5852ad.jpg
# 1ce47c78-7c29-4f2b-b614-657907880f8b_jpg.rf.c93436c046f0bf8cb17b30662d58fc1a.jpg
# 1a1afd54-bc00-4d10-852e-e2850fffddac_jpg.rf.373f5599cdcd9b517478e3e8b1b09632.jpg
# 1ce47c78-7c29-4f2b-b614-657907880f8b_jpg.rf.c049152a4b691380712b5fb656bc7c03.jpg
# 1ce47c78-7c29-4f2b-b614-657907880f8b_jpg.rf.861cccc3924f7a5acf5e3771d4c2d6e2.jpg
# 1caa69fb-f2f3-4cae-a5ec-cf51c73dc970_jpg.rf.2e1e63a606eaafe604855649aed33f8e.jpg
# 1babad6a-7892-43d5-a283-37deab72aab4_jpg.rf.fb9ea25e30ea1eaf802a0074a796ea57.jpg
# 1d4677c1-ed2f-4321-a555-f5610040931c_jpg.rf.2a960401d7b0ced4e1de44aa79db65c0.jpg
# 1d2a9292-b7f1-41f2-8af5-5ba03d535650_jpg.rf.fdce19083b97010d09066ab8a68e9602.jpg
# 1_99_jpg.rf.3248efec957fbda915d13753a52391e1.jpg
# 1c8349d1-9476-4591-87f8-52209721afc3_jpg.rf.826307da454f05cb7ea5fb33ba5f7ce0.jpg
# 1caa69fb-f2f3-4cae-a5ec-cf51c73dc970_jpg.rf.ca019ead47eb4b402af242bf18e755b7.jpg
# 1_99_jpg.rf.47852ac1f408f55c177b858822934c2b.jpg
# 1cdeaf6c-0167-47d9-9190-ca728b543f40_jpg.rf.1c44dd8314140067656b4d6617403b56.jpg
# 1_98_jpg.rf.3fa6bf651077992adf69a9dbe9e97261.jpg
# 1babad6a-7892-43d5-a283-37deab72aab4_jpg.rf.c58f1f262274bb4c2d064b17622ec7bb.jpg
# 1babad6a-7892-43d5-a283-37deab72aab4_jpg.rf.a43e603b9c45bc3681d4b8f6cae1049d.jpg
# 1_99_jpg.rf.e963df4ff254f7b67f79cacb18dec2ae.jpg
# 1_97_jpg.rf.b0ed603fc9b9399035dbaaca68a797cc.jpg
# 1_98_jpg.rf.8e0a77aebe9a2e02556d10ff4dffe6d6.jpg
# 1d2a9292-b7f1-41f2-8af5-5ba03d535650_jpg.rf.6f3d830d89119364072ae93388ee8a99.jpg
# 1c8349d1-9476-4591-87f8-52209721afc3_jpg.rf.5f13b74265be6a0e53ece260a57410ce.jpg
# 1_98_jpg.rf.e3bb76a7ab0f45c8f6d86ff48c09ce44.jpg
# 1d2a9292-b7f1-41f2-8af5-5ba03d535650_jpg.rf.baf29fa84dd63656d034459de7580163.jpg
# 1c992e2b-108a-4e3c-859d-ae84d6f8ce7f_jpg.rf.c95fd251bba347a5d7f6f48c6852001b.jpg
# 1cdeaf6c-0167-47d9-9190-ca728b543f40_jpg.rf.18a395e79583d5b3aa7849986d56fed2.jpg
# 1c8480e0-7f02-412e-bdf4-bea8ca79d7ff_jpg.rf.de6f8b803e3cb3b36f5ddcdf0d4c9d8c.jpg
# 1c8480e0-7f02-412e-bdf4-bea8ca79d7ff_jpg.rf.9a3799646d46a064ba190167d10ac53e.jpg
# 1c8349d1-9476-4591-87f8-52209721afc3_jpg.rf.c1cf2f567af4ca33c98d30ea17b86c7c.jpg
# 1c992e2b-108a-4e3c-859d-ae84d6f8ce7f_jpg.rf.b6eb384edd6afb384becce053ee91591.jpg
# 1c992e2b-108a-4e3c-859d-ae84d6f8ce7f_jpg.rf.19f58a704a68e3e726fc195fa3d30207.jpg
# 1a1afd54-bc00-4d10-852e-e2850fffddac_jpg.rf.480d53c716111af0cee0d9cf30d04048.jpg
# 1cdeaf6c-0167-47d9-9190-ca728b543f40_jpg.rf.4a9dabe00a671089ae9a733bd59a223b.jpg
# 1a1afd54-bc00-4d10-852e-e2850fffddac_jpg.rf.4f13d3799091ae5e1c63594807e7be18.jpg
# 200007_jpg.rf.4e2d3f60b026f1e263912d0c91a0a04c.jpg
# 1da54983-4378-4161-a79b-30d9cc9e03f1_jpg.rf.f74868c0f6da8e3b56d11583b3d54abf.jpg
# 1da54983-4378-4161-a79b-30d9cc9e03f1_jpg.rf.cb9d3e8e342d7dd618e0b6b799c0e9d6.jpg
# 1e162678-80b4-48c4-848e-1a175f3230e7_jpg.rf.01d76d072f70780ac9da52a4d1f08983.jpg
# 1d4677c1-ed2f-4321-a555-f5610040931c_jpg.rf.4cedebd92a7e55f470df1856c4425e71.jpg
# 200010_jpg.rf.8cacd703f2929110d8aa337069ac15b7.jpg
# 1e851b74-c436-43b7-b3b1-92ba96c0ff15_jpg.rf.f21732c6d1d7016492b319f73b53aeb0.jpg
# 200003_jpg.rf.ffb2e85dd401486b938b62cc59766d1e.jpg
# 200003_jpg.rf.31ee226099c50a4a2b79d8265195bc5e.jpg
# 1d7c97f2-39f6-43fa-bf94-ddb61e829b53_jpg.rf.1a493c9d9bbbd234ee3973138f833503.jpg
# 1e162678-80b4-48c4-848e-1a175f3230e7_jpg.rf.2a768e2549da3eda35eb17ca86cc5c97.jpg
# 1e61b317-a17b-4d6b-8e68-239b97bbbbd0_jpg.rf.ee5b9cde9f44160999f8622b61e0cb0c.jpg
# 200007_jpg.rf.9d8bac16a4281fa0bdaa457703badd36.jpg
# 200002_jpg.rf.6e288f087e178efb9f0b1a4ecededa75.jpg
# 1f2d1506-23c8-4432-adcd-776eb5afdeec_jpg.rf.01790bb17566408befa02e51360cbc75.jpg
# 1f2d1506-23c8-4432-adcd-776eb5afdeec_jpg.rf.d191f1e01f2ad8a921ec7585695eba0f.jpg
# 200004_jpg.rf.0df2253004c911d503da626547e83514.jpg
# 200004_jpg.rf.f0b621bb33365890ae248a51fcd1855c.jpg
# 200010_jpg.rf.8553bb9020a1a5ff40dca68634680478.jpg
# 200002_jpg.rf.da37c11c7e936d55d4e51991a12847c3.jpg
# 200003_jpg.rf.61e443db7231c1f09c7cba405865c92f.jpg
# 1d797f4e7f3a3ba45ac26472b19afa0e_jpg.rf.824d1e3c95e89a32b6c7d7e462e39d7f.jpg
# 200002_jpg.rf.c024c9349f32bb61bd94d7cf4933074b.jpg
# 1e851b74-c436-43b7-b3b1-92ba96c0ff15_jpg.rf.a2575b590ed6c00ebd888b4f85cfbac5.jpg
# 1d797f4e7f3a3ba45ac26472b19afa0e_jpg.rf.7a71da94dd04dce79b3bc82399825f49.jpg
# 200007_jpg.rf.c318f54cab230da673c9a34478091713.jpg
# 200004_jpg.rf.d405c749ba5f16a220adf1ae676b728c.jpg
# 1e61b317-a17b-4d6b-8e68-239b97bbbbd0_jpg.rf.0e3381b179baa3550bcf922a6543ec28.jpg
# 1d797f4e7f3a3ba45ac26472b19afa0e_jpg.rf.199e275547225430d64df30fe473a0ba.jpg
# 1f2d1506-23c8-4432-adcd-776eb5afdeec_jpg.rf.c0dad27eb3a9616d5793beb3cd5e462d.jpg
# 1da54983-4378-4161-a79b-30d9cc9e03f1_jpg.rf.f1d35e441fdbda906fc1a94b178aa9be.jpg
# 1d7c97f2-39f6-43fa-bf94-ddb61e829b53_jpg.rf.adb6102ccb4d97683067cf29d061a544.jpg
# 1d4677c1-ed2f-4321-a555-f5610040931c_jpg.rf.ba472715a0c5837289d0f612546cac5b.jpg
# 1e162678-80b4-48c4-848e-1a175f3230e7_jpg.rf.7390dab716b247d557058942c71e2e0a.jpg
# 1d7c97f2-39f6-43fa-bf94-ddb61e829b53_jpg.rf.71db4fb8601cd4ffe4afd0c9b38d5027.jpg
# 1e61b317-a17b-4d6b-8e68-239b97bbbbd0_jpg.rf.fe7388a7a2d7d38869e73c876a0dad00.jpg
# 1e851b74-c436-43b7-b3b1-92ba96c0ff15_jpg.rf.b0f29e8eb08338dfa11d4f0f00b61ca6.jpg
# 200054_jpg.rf.a10df585943be0ddd0defa73812f0593.jpg
# 200044_jpg.rf.f4839a3ab39da8fe397a4dcb35f17188.jpg
# 200063_jpg.rf.d5eb94bc42574559493bfbce32a199c1.jpg
# 200079_jpg.rf.bb29b5f3b82b2b7234a826050919d65d.jpg
# 200079_jpg.rf.03fea65c3e2e4ce734022b1e786585b6.jpg
# 200072_jpg.rf.18c14914be4caa4e1c19055fdb4a75f8.jpg
# 200054_jpg.rf.1d8f1ae15250df3f3b822e62d06a7506.jpg
# 200072_jpg.rf.f01e47379cf56ea072b3c0f0465fb90f.jpg
# 200077_jpg.rf.09d92db1bafd8996336f0ef879b5da85.jpg
# 200063_jpg.rf.2939661d6eac6d1dc191c69591b66eae.jpg
# 200044_jpg.rf.ed6fe37ba9931d76111c844020d578f1.jpg
# 200044_jpg.rf.9c3428b88a4f3f3141c3448b2e968a40.jpg
# 200021_jpg.rf.f7d5ff688f2dcc9070ac97ee3eba4576.jpg
# 200028_jpg.rf.b3af617c957ad93ef52e38ed07d05bc1.jpg
# 200010_jpg.rf.ccf2ca7b8af1ffecdc5f72de5e77e244.jpg
# 200081_jpg.rf.d019d482acd0be9ec6c68fae1a5de7c9.jpg
# 200021_jpg.rf.83c8b0d1945d2adad139cbb2f6777008.jpg
# 200079_jpg.rf.d23173e333f7ab31e226af9958254bb5.jpg
# 200069_jpg.rf.cceb1d05b89339e8f229e2190648276e.jpg
# 200061_jpg.rf.bc1b3bbe42c731d9dfc282191ef22814.jpg
# 200077_jpg.rf.d5322bc63749fe2a178e8d8ed9a7e9a7.jpg
# 200071_jpg.rf.93720997ce3f5fd52a76fb56a2039f84.jpg
# 200069_jpg.rf.52f265ac4cf9f6c57a6bb1a7e11ae35a.jpg
# 200069_jpg.rf.ac989f47e2f07087c9c60e29f05bf435.jpg
# 200028_jpg.rf.77cebe0d61446cac83ff7be4f4841172.jpg
# 200072_jpg.rf.2d349efb45ce8cac1cf67eebfedcf7d8.jpg
# 200028_jpg.rf.d1e8283e5280ba071e8d7ffed414bc40.jpg
# 200077_jpg.rf.3faf07e92e060afada7d12b16ebac5c9.jpg
# 200024_jpg.rf.ca96c618e6d269ec22f1f5adf2395016.jpg
# 200061_jpg.rf.1f33a2a19e02d100c92b8933a3ca522c.jpg
# 200071_jpg.rf.57d1b2d66c2bf05cc2945d422689f3f0.jpg
# 200024_jpg.rf.a32ed0cfed986c13f004d9647b090e2c.jpg
# 200054_jpg.rf.5b8e9d5e6d1db8c2325dc9342c3238d7.jpg
# 200024_jpg.rf.fb3de71cf0e37126ae48cfb629557153.jpg
# 200061_jpg.rf.50bd398bcd6a9c9dbb532a3911693b3f.jpg
# 200021_jpg.rf.5113a603171594ccd7cf8ef5f53f3162.jpg
# 200063_jpg.rf.21709c88a3d03a6c07dffafb14c3043e.jpg
# 200071_jpg.rf.a360157ed95808900f2f11cccc015adc.jpg
# 200081_jpg.rf.85000a0c0d93c1c7995ffe464974a7e7.jpg
# 200109_jpg.rf.02ec102d1ade1701556b78d942e27567.jpg
# 200124_jpg.rf.66a02de964d80503a8e446c6b10bd0a0.jpg
# 200109_jpg.rf.e261158ce5655d2024105c7d5bdefd7b.jpg
# 200081_jpg.rf.f4f915d82275c850bc8a642f836d922d.jpg
# 200105_jpg.rf.c24587a2d826d30cd3a853d6d549ebb6.jpg
# 200097_jpg.rf.95e7d3984e18b72c9f90d2eaf88210d1.jpg
# 200103_jpg.rf.5043b743824e5c180b2819971ab7bf02.jpg
# 200108_jpg.rf.abb44f883c799c42faaa7ae8c7ed9bf0.jpg
# 200086_jpg.rf.af14449f33452c77a9433b2b18259c73.jpg
# 200103_jpg.rf.a0a8dc9b193a64ba20b847c3f1d63a21.jpg
# 200149_jpg.rf.4f71db2a72a28eefed06275b06a73c47.jpg
# 200108_jpg.rf.5d70fb8b5242a392eb7d04cd5f8a798d.jpg
# 200088_jpg.rf.107fdfe2b396130db89a9720dc6a1db0.jpg
# 200114_jpg.rf.85cb29f7d9d19e487a875ac9edf9a064.jpg
# 200144_jpg.rf.b9d9fb7719a276a043665a07ddeab709.jpg
# 200114_jpg.rf.efebdbcb8c6d345a7ae1aa4389d4c20f.jpg
# 200103_jpg.rf.2ce83366575abb56d168b3d46422a930.jpg
# 200083_jpg.rf.e2a897e6c541e5d35d007c6f692b8948.jpg
# 200114_jpg.rf.63b1719afa320ecb3d9882fa3a8b2409.jpg
# 200088_jpg.rf.4db5e8d041a343e243646e89ed2e989b.jpg
# 200097_jpg.rf.1e916cd0d0fd8ee2780788bd386e5dc2.jpg
# 200105_jpg.rf.e455a1523447e828416e926a9e146a8c.jpg
# 200083_jpg.rf.0b8f206cbc5fa64871becf5a82731b38.jpg
# 200105_jpg.rf.50963928593de7b68a33c5e6be350fb0.jpg
# 200083_jpg.rf.770db274921ca2f6a8e028b00f0913d8.jpg
# 200149_jpg.rf.8ff625cefa9098a9f26e693fac80d10b.jpg
# 200116_jpg.rf.d1aab6e9ad5d0d1e51d451fc5c03688a.jpg
# 200108_jpg.rf.f42352615e09cad18d4974eea8d7358a.jpg
# 200116_jpg.rf.af4a84a72d774703895847e8a9ec121a.jpg
# 200116_jpg.rf.fd6cce2466837da4de24fa6ab2275ea1.jpg
# 200088_jpg.rf.8083739997d0d51e777c0e11172948b3.jpg
# 200144_jpg.rf.c7966d5999768d2d99e3a2ae4e703939.jpg
# 200124_jpg.rf.aeb40a3e63aab0bd375b9b11e4681699.jpg
# 200144_jpg.rf.3e0024a5aeb0d27a13b40f0bd4148c71.jpg
# 200086_jpg.rf.55ecc93b4b19d608df247fb55e46f129.jpg
# 200086_jpg.rf.4504231dfea685997855fae5326c71ca.jpg
# 200109_jpg.rf.1f55cb1622d71ed353df3add40008f61.jpg
# 200124_jpg.rf.788105e6a16dfed0736eb18e9323e0d4.jpg
# 200097_jpg.rf.bf76ee1220e08692b2d8c9aa32c0d72a.jpg
# 200187_jpg.rf.f47f728d5e76bff494e006aa3e6a116a.jpg
# 200200_jpg.rf.072dcef327698435e96a500071a89600.jpg
# 200174_jpg.rf.5d42964d82c08e9a2b68c0bff5bb15e3.jpg
# 200150_jpg.rf.c662335fb0e445023677947460bd311e.jpg
# 200149_jpg.rf.cfa7cfd34ba93293fa9e1b306cff082b.jpg
# 200172_jpg.rf.d648037efdb98432dc9f2c893f5b371a.jpg
# 200178_jpg.rf.6b0ad66d1be85558ed11f824dbc79335.jpg
# 200188_jpg.rf.2fed242c02f6d32f9fabd05edfc695f0.jpg
# 200170_jpg.rf.be3fe19bccdc655f758efff6d08120d5.jpg
# 200178_jpg.rf.c5af22183b0c8a92dd1d5c24094ed7ba.jpg
# 200200_jpg.rf.620f80b56387bacda5925cb717cd7bc2.jpg
# 200188_jpg.rf.70529e9c7c50df9932f97169ba1d8a8b.jpg
# 200170_jpg.rf.6ddcfcabcc85021eb6fc116487a5db83.jpg
# 200210_jpg.rf.16a9044effb417dca66fa41aa2cb26cb.jpg
# 200190_jpg.rf.8bf708c34acfc12790823f71340595ae.jpg
# 200190_jpg.rf.a52cda87f15cea71d9838e2abf38d3f9.jpg
# 200187_jpg.rf.c46b067e46893b9fa11d325f8722cca2.jpg
# 200159_jpg.rf.42db94aebcfa6940ac16840a6f22929e.jpg
# 200150_jpg.rf.d775188daff0bd747d7241a8d3035371.jpg
# 200210_jpg.rf.3526a9a5b1ddad27c6ad5bce405c248f.jpg
# 200178_jpg.rf.64e0f1d8d3d6e0b7dfb11f693ccf97e7.jpg
# 200190_jpg.rf.62d4d8e96555e8e6a8dd9b336ec7dd4f.jpg
# 200174_jpg.rf.65a0292062577fd34f5045667fc96ecc.jpg
# 200198_jpg.rf.d61f8fa40c4efb3902771f83fddb28c3.jpg
# 200150_jpg.rf.bf8bdf1935559b2bcc9c68ca9c130293.jpg
# 200159_jpg.rf.e2482ef832f45bf50e7260a2a47d3b6e.jpg
# 200187_jpg.rf.d0a3b4a0e43eb44843af8d64dcae3652.jpg
# 200174_jpg.rf.96cca26c283b89339bcc82d9448bead7.jpg
# 200200_jpg.rf.b34b3c897d3523518d93619f4207fa11.jpg
# 200170_jpg.rf.391f2cb1350da27ff680afd93a8156f5.jpg
# 200172_jpg.rf.18dd4124a27d2523166d9bd57ef9f418.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the directory where the train images are stored
test_dir = '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/train'

# Create an instance of ImageDataGenerator for loading test data
test_datagen = ImageDataGenerator(rescale=1.0/255)  # Rescale pixel values to [0, 1]

# Load test images from directory and organize them into fire and smoke classes
test_data = test_datagen.flow_from_directory(
    test_dir,  # The directory containing test images organized by class
    target_size=(224, 224),  # Adjust this to the size expected by your model
    batch_size=32,  # You can change the batch size if needed
    class_mode='categorical',  # Use 'categorical' if you have more than 2 classes
    shuffle=False  # Do not shuffle so predictions can be matched with filenames
)

# Print the classes to ensure the images are separated correctly
print("Classes found: ", test_data.class_indices)

# You can also print the filenames to check the images are loaded correctly
print("Filenames: ", test_data.filenames)
# Out:
# Found 0 images belonging to 0 classes.
# Classes found:  {}
# Filenames:  []

# %%
print("Number of test samples: ", test_data.samples)
# Out:
# Number of test samples:  0

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),  # Ensure this matches your model's input shape
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 0 images belonging to 0 classes.

# %%
images, labels = next(test_data)
print(f"Batch shape: {images.shape}, Labels shape: {labels.shape}")
# Out:
# Batch shape: (0, 224, 224, 3), Labels shape: (0, 0)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1.0/255)  # Normalize pixel values

train_data = datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/train',
    target_size=(224, 224),  # Update height and width to match your images
    batch_size=32,
    class_mode='categorical'
)

validation_data = datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/Fire and Smoke',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 2 classes.

# %%
print(f"Number of training samples: {train_data.samples}")
print(f"Number of validation samples: {validation_data.samples}")
# Out:
# Number of training samples: 0
# Number of validation samples: 0

# %%
import matplotlib.pyplot as plt

def plot_training_performance(history):
    # Plot training & validation accuracy values
    epochs = range(1, len(history.history['accuracy']) + 1)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # Accuracy plot
    ax1.plot(epochs, history.history['accuracy'], 'b-', label='Training Accuracy')
    ax1.plot(epochs, history.history['val_accuracy'], 'r-', label='Validation Accuracy')
    ax1.set_title('Model Accuracy', fontsize=14)
    ax1.set_xlabel('Epochs', fontsize=12)
    ax1.set_ylabel('Accuracy', fontsize=12)
    ax1.legend(loc='lower right')
    ax1.grid(True)

    # Loss plot
    ax2.plot(epochs, history.history['loss'], 'b-', label='Training Loss')
    ax2.plot(epochs, history.history['val_loss'], 'r-', label='Validation Loss')
    ax2.set_title('Model Loss', fontsize=14)
    ax2.set_xlabel('Epochs', fontsize=12)
    ax2.set_ylabel('Loss', fontsize=12)
    ax2.legend(loc='upper right')
    ax2.grid(True)

    # Show plots
    plt.tight_layout()
    plt.show()

# Example usage:
# plot_training_performance(history)

# %% [markdown]
# ### **Step 8: Saving the Trained Model**

# %%
# Save the trained model to Google Drive
model.save('/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# To load the model later
model = tf.keras.models.load_model('/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
train_data = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset/train',  # Full path to your training data
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 0 images belonging to 0 classes.

# %%
# Save the trained model to Google Drive
model.save('/content/drive/MyDrive/Thesis Paper/Thesis Papers(1-20)/Fire and smoke dataset.h5')

# To load the model later
# model = tf.keras.models.load_model('/content/drive/MyDrive/fire_smoke_detection_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## **Step 9: Real-Time Prediction on New Images**

# %%
# Load and preprocess a test image
test_img = cv2.imread('fire039_jpg.rf.c4b621d3b6997aeb3454c4df5b980578.jpg')  # Specify the full path to the image

# %%
import cv2
import numpy as np

# Load the image
test_img = cv2.imread('fire039_jpg.rf.c4b621d3b6997aeb3454c4df5b980578.jpg')

# Check if the image is loaded correctly
if test_img is None:
    print("Failed to load image. Check the file path and format.")
else:
    # Resize the image to the input size required by the model
    test_img_resized = cv2.resize(test_img, (224, 224))

    # Normalize the image by dividing by 255.0
    test_img_normalized = test_img_resized / 255.0

    # Expand dimensions to add a batch dimension (1, 224, 224, 3)
    test_img_array = np.expand_dims(test_img_normalized, axis=0)

    # Now you can use test_img_array for prediction
    prediction = model.predict(test_img_array)
    if prediction > 0.5:
        print('Fire Detected')
    else:
        print('No Fire Detected')
# Out:
# Failed to load image. Check the file path and format.

# %%
# Load and preprocess a test image
test_img = cv2.imread('/path_to_image/test_image.jpg')
test_img_resized = cv2.resize(test_img, (224, 224))
test_img_array = np.expand_dims(test_img_resized, axis=0) / 255.0  # Normalize the image

# Predict using the trained model
prediction = model.predict(test_img_array)
if prediction > 0.5:
    print('Fire Detected')
else:
    print('No Fire Detected')
